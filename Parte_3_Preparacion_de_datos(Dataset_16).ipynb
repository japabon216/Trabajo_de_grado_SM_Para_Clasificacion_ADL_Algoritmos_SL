# %% [markdown]
# <a href="https://colab.research.google.com/github/japabon216/Trabajo_de_grado_SM_Para_Clasificacion_ADL_Algoritmos_SL/blob/main/Parte_3_Preparacion_de_datos(Dataset_16).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import os
import csv
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Funciones

# %%
import random

def resample_dataframe(df):
    original_frequency = df['Frequency'].iloc[0]

    if original_frequency == 50:
        return df

    elif original_frequency > 50:
        new_rows = int(len(df) * (50 / original_frequency))
        drop_indices = random.sample(range(len(df)), len(df) - new_rows)

        new_df = df.drop(drop_indices).copy()

        new_df['Frequency'] = 50

        return new_df

    else:
        new_frequency = 50

        grouped = df.groupby('User')

        resampled_data = []

        for group_name, group_data in grouped:
            desired_rows = int(len(group_data) * (new_frequency / group_data['Frequency'].iloc[0]))

            repeated_group = pd.concat([group_data] * (desired_rows // len(group_data)))

            remaining_rows = desired_rows - len(repeated_group)
            if remaining_rows > 0:
                additional_rows = group_data.sample(n=remaining_rows, replace=True)
                repeated_group = pd.concat([repeated_group, additional_rows])

            ordered_group = repeated_group.sort_index()

            resampled_data.append(ordered_group)

        resampled_data = pd.concat(resampled_data, ignore_index=True)
        resampled_data['Frequency'] = 50
        return resampled_data

# %%
# Funcion para ver los valores válidos de un acelerometro
import plotly.graph_objects as go

def grafico_acelerometro_valido(df):

    valores_nulos = df[['X_Acc', 'Y_Acc', 'Z_Acc']].isnull().any(axis=1).sum()
    valores_validos = len(df) - valores_nulos


    # Calcular los porcentajes
    porcentaje_nulos = (valores_nulos / len(df)) * 100
    porcentaje_validos = (valores_validos / len(df)) * 100

    labels = ['Valores nulos', 'Valores válidos']
    values = [porcentaje_nulos, porcentaje_validos]

    fig = go.Figure(data=[go.Pie(labels=labels, values=values)])

    fig.update_layout(
        title="Porcentaje de valores nulos y valores válidos en el acelerómetro"
    )

    fig.show()

# %%
# Valores máximos y mínimos en el acelerometro
import plotly.graph_objects as go

def grafico_acelerometro_max_min(df):

    columnas = ['X_Acc', 'Y_Acc', 'Z_Acc']
    df_columnas = df[columnas]

    media = df_columnas.mean()
    mediana = df_columnas.median()
    maximo = df_columnas.max()
    minimo = df_columnas.min()

    desplazamiento = (media.max() - media.min()) * 0.05

    fig = go.Figure()

    fig.add_trace(go.Bar(
        x=columnas,
        y=media,
        name='Media',
        marker_color='rgba(55, 128, 191, 0.7)'
    ))

    fig.add_trace(go.Bar(
        x=columnas,
        y=mediana,
        name='Mediana',
        marker_color='rgba(219, 64, 82, 0.7)'
    ))

    for columna, valor_max, valor_min in zip(columnas, maximo, minimo):
        fig.add_annotation(
            x=columna,
            y=media.max() + desplazamiento,
            text="Máximo: " + str(valor_max),
            showarrow=False,
            font=dict(color='green')
        )
        fig.add_annotation(
            x=columna,
            y=media.min() - desplazamiento,
            text="Mínimo: " + str(valor_min),
            showarrow=False,
            font=dict(color='purple')
        )

    fig.update_layout(
        title="Media, Mediana y Etiquetas de Máximo y Mínimo de las columnas del acelerometro",
        xaxis_title="Columnas",
        yaxis_title="Valor"
    )

    fig.show()

# %%
#Valores validos giroscopio

def grafico_giroscopio_valido(df):

    valores_nulos = df[['X_Gyro', 'Y_Gyro', 'Z_Gyro']].isnull().any(axis=1).sum()
    valores_validos = len(df) - valores_nulos

    porcentaje_nulos = (valores_nulos / len(df)) * 100
    porcentaje_validos = (valores_validos / len(df)) * 100

    labels = ['Valores nulos', 'Valores válidos']
    values = [porcentaje_nulos, porcentaje_validos]

    fig = go.Figure(data=[go.Pie(labels=labels, values=values)])

    fig.update_layout(
        title="Porcentaje de valores nulos y valores válidos en el giroscopio"
    )
    fig.show()

# %%
#Valores máximos y mínimos giroscopio

def grafico_giroscopio_max_min(df):

    columnas = ['X_Gyro', 'Y_Gyro', 'Z_Gyro']
    df_columnas = df[columnas]

    media = df_columnas.mean()
    mediana = df_columnas.median()
    maximo = df_columnas.max()
    minimo = df_columnas.min()

    desplazamiento = (media.max() - media.min()) * 0.05

    fig = go.Figure()

    fig.add_trace(go.Bar(
        x=columnas,
        y=media,
        name='Media',
        marker_color='rgba(55, 128, 191, 0.7)'
    ))

    fig.add_trace(go.Bar(
        x=columnas,
        y=mediana,
        name='Mediana',
        marker_color='rgba(219, 64, 82, 0.7)'
    ))

    for columna, valor_max, valor_min in zip(columnas, maximo, minimo):
        fig.add_annotation(
            x=columna,
            y=media.max() + desplazamiento,
            text="Máximo: " + str(valor_max),
            showarrow=False,
            font=dict(color='green')
        )
        fig.add_annotation(
            x=columna,
            y=media.min() - desplazamiento,
            text="Mínimo: " + str(valor_min),
            showarrow=False,
            font=dict(color='purple')
        )

    fig.update_layout(
        title="Media, Mediana y Etiquetas de Máximo y Mínimo de las columnas del giroscopio",
        xaxis_title="Columnas",
        yaxis_title="Valor"
    )

    fig.show()

# %%
#Porcentaje de actividades validas

def grafico_activity(df):

    columna_actividad = df['Activity']

    valores_validos = columna_actividad.notnull().sum()
    valores_nulos = columna_actividad.isnull().sum()

    # Calcular los porcentajes
    porcentaje_validos = (valores_validos / len(columna_actividad)) * 100
    porcentaje_nulos = (valores_nulos / len(columna_actividad)) * 100

    labels = ['Valores válidos', 'Valores nulos']
    values = [porcentaje_validos, porcentaje_nulos]

    fig = go.Figure(data=[go.Pie(labels=labels, values=values)])

    fig.update_layout(
        title="Porcentaje de valores nulos y valores válidos en la columna 'Activity'"
    )

    fig.show()

# %% [markdown]
# # Dataset Número 16. The extrasensory dataset

# %% [markdown]
# #**Smartwatch**

# %% [markdown]
# ###Eliminación de las filas NaN de Activity

# %%
watch_1 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_2/watch_1.dat', delimiter=' ')
# Out:
# <ipython-input-7-37ddfa5d112e>:1: DtypeWarning:
#
# Columns (4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
watch_1
# Out:
#                         TimeStamp  X_Acc   Y_Acc   Z_Acc Activity Activity_2  \
# 0         2015-10-05 16:06:01.124   24.0   -48.0 -1024.0  SITTING        NaN
# 1         2015-10-05 16:06:01.164   16.0   -40.0 -1048.0  SITTING        NaN
# 2         2015-10-05 16:06:01.204   -8.0   -48.0 -1016.0  SITTING        NaN
# 3         2015-10-05 16:06:01.244    0.0   -56.0 -1008.0  SITTING        NaN
# 4         2015-10-05 16:06:01.284    0.0   -48.0 -1040.0  SITTING        NaN
# ...                           ...    ...     ...     ...      ...        ...
# 34592809  2015-12-07 16:57:32.513   88.0   440.0   696.0  WALKING        NaN
# 34592810  2015-12-07 16:57:32.553  -56.0   -32.0  -984.0  WALKING        NaN
# 34592811  2015-12-07 16:57:32.593 -440.0   904.0   408.0  WALKING        NaN
# 34592812  2015-12-07 16:57:32.633 -208.0  1472.0   944.0  WALKING        NaN
# 34592813  2015-12-07 16:57:32.673 -424.0   816.0   456.0  WALKING        NaN
#
#          Activity_3  User
# ...

# %%
watch_1.dropna(subset=['Activity'], inplace=True)

# %%
watch_1
# Out:
#                         TimeStamp  X_Acc   Y_Acc   Z_Acc Activity Activity_2  \
# 0         2015-10-05 16:06:01.124   24.0   -48.0 -1024.0  SITTING        NaN
# 1         2015-10-05 16:06:01.164   16.0   -40.0 -1048.0  SITTING        NaN
# 2         2015-10-05 16:06:01.204   -8.0   -48.0 -1016.0  SITTING        NaN
# 3         2015-10-05 16:06:01.244    0.0   -56.0 -1008.0  SITTING        NaN
# 4         2015-10-05 16:06:01.284    0.0   -48.0 -1040.0  SITTING        NaN
# ...                           ...    ...     ...     ...      ...        ...
# 34592809  2015-12-07 16:57:32.513   88.0   440.0   696.0  WALKING        NaN
# 34592810  2015-12-07 16:57:32.553  -56.0   -32.0  -984.0  WALKING        NaN
# 34592811  2015-12-07 16:57:32.593 -440.0   904.0   408.0  WALKING        NaN
# 34592812  2015-12-07 16:57:32.633 -208.0  1472.0   944.0  WALKING        NaN
# 34592813  2015-12-07 16:57:32.673 -424.0   816.0   456.0  WALKING        NaN
#
#          Activity_3  User
# ...

# %%
watch_1.reset_index(drop=True, inplace=True)

# %%
watch_1.to_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_NAN/watch_1.dat',index=False)

# %%
watch_1.to_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_NAN/watch_1.dat',index=False)
watch_2 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_2/watch_2.dat', delimiter=' ')
# Out:
# <ipython-input-27-a66727adec55>:1: DtypeWarning:
#
# Columns (4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.

# %%
watch_2.dropna(subset=['Activity'], inplace=True)

# %%
watch_2.reset_index(drop=True, inplace=True)

# %%
watch_2
# Out:
#                         TimeStamp  X_Acc  Y_Acc   Z_Acc             Activity  \
# 0         2015-08-04 12:20:21.125   -8.0 -200.0 -1008.0              SITTING
# 1         2015-08-04 12:20:21.165  -16.0 -192.0 -1048.0              SITTING
# 2         2015-08-04 12:20:21.205  -24.0 -200.0  -992.0              SITTING
# 3         2015-08-04 12:20:21.245   -8.0 -192.0  -984.0              SITTING
# 4         2015-08-04 12:20:21.285    8.0 -208.0 -1000.0              SITTING
# ...                           ...    ...    ...     ...                  ...
# 24384233  2015-10-16 10:31:23.410 -280.0  552.0   824.0  STANDING_AND_MOVING
# 24384234  2015-10-16 10:31:23.450 -296.0  528.0   848.0  STANDING_AND_MOVING
# 24384235  2015-10-16 10:31:23.490 -288.0  528.0   840.0  STANDING_AND_MOVING
# 24384236  2015-10-16 10:31:23.530 -272.0  528.0   864.0  STANDING_AND_MOVING
# 24384237  2015-10-16 10:31:23.570 -272.0  528.0   832.0  STANDING_AND_MOVING
#
#          Activity_2 Activity_3  User
# ...

# %%
watch_2.to_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_NAN/watch_2.dat',index=False)

# %%
watch_3 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_2/watch_3.dat', delimiter=' ')
# Out:
# <ipython-input-2-443edd418be7>:1: DtypeWarning: Columns (4,5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   watch_3 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_2/watch_3.dat', delimiter=' ')

# %%
watch_3.dropna(subset=['Activity'], inplace=True)
watch_3.reset_index(drop=True, inplace=True)

# %%
watch_3
# Out:
#                         TimeStamp  X_Acc  Y_Acc   Z_Acc   Activity Activity_2  \
# 0         2015-10-15 10:48:40.022  -32.0 -664.0  -776.0    SITTING        NaN
# 1         2015-10-15 10:48:40.062    8.0  -24.0 -1000.0    SITTING        NaN
# 2         2015-10-15 10:48:40.102    0.0  -16.0 -1040.0    SITTING        NaN
# 3         2015-10-15 10:48:40.142    0.0  -16.0 -1000.0    SITTING        NaN
# 4         2015-10-15 10:48:40.182    0.0   -8.0 -1000.0    SITTING        NaN
# ...                           ...    ...    ...     ...        ...        ...
# 29700247  2015-09-16 09:01:13.704 -576.0  328.0  -672.0  BICYCLING        NaN
# 29700248  2015-09-16 09:01:13.744 -576.0  384.0  -752.0  BICYCLING        NaN
# 29700249  2015-09-16 09:01:13.784 -576.0  336.0  -728.0  BICYCLING        NaN
# 29700250  2015-09-16 09:01:13.824 -568.0  400.0  -744.0  BICYCLING        NaN
# 29700251  2015-09-16 09:01:13.864 -536.0  408.0  -720.0  BICYCLING        NaN
#
#          Activity_3  User
# ...

# %%
watch_3.to_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_NAN/watch_3.dat',index=False)

# %% [markdown]
# ###Actividades unicas del watch_1

# %%
watch_1 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_NAN/watch_1.dat', delimiter=',')
# Out:
# <ipython-input-2-23afa775422d>:1: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   watch_1 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_NAN/watch_1.dat', delimiter=',')

# %%
watch_1_copy = watch_1.copy()
watch_1_copy.drop(columns=['Activity_3'], inplace=True)
watch_1_copy['Activity'] = watch_1_copy['Activity'].fillna('') + '-' + watch_1_copy['Activity_2'].fillna('')
watch_1_copy.drop(columns=['Activity_2'], inplace=True)

# %%
watch_1_copy
# Out:
#                         TimeStamp  X_Acc   Y_Acc   Z_Acc  Activity  User
# 0         2015-10-05 16:06:01.124   24.0   -48.0 -1024.0  SITTING-     1
# 1         2015-10-05 16:06:01.164   16.0   -40.0 -1048.0  SITTING-     1
# 2         2015-10-05 16:06:01.204   -8.0   -48.0 -1016.0  SITTING-     1
# 3         2015-10-05 16:06:01.244    0.0   -56.0 -1008.0  SITTING-     1
# 4         2015-10-05 16:06:01.284    0.0   -48.0 -1040.0  SITTING-     1
# ...                           ...    ...     ...     ...       ...   ...
# 30461059  2015-12-07 16:57:32.513   88.0   440.0   696.0  WALKING-    11
# 30461060  2015-12-07 16:57:32.553  -56.0   -32.0  -984.0  WALKING-    11
# 30461061  2015-12-07 16:57:32.593 -440.0   904.0   408.0  WALKING-    11
# 30461062  2015-12-07 16:57:32.633 -208.0  1472.0   944.0  WALKING-    11
# 30461063  2015-12-07 16:57:32.673 -424.0   816.0   456.0  WALKING-    11
#
# [30461064 rows x 6 columns]

# %%
unique_activities = watch_2['Activity'].unique()
unique_activities
# Out:
# array(['SITTING-', 'SITTING-COMPUTER_WORK', 'WALKING-',
#        'STANDING_AND_MOVING-COOKING', 'LYING_DOWN-',
#        'STANDING_AND_MOVING-BATHING_-_SHOWER',
#        'STANDING_AND_MOVING-DRESSING', 'SITTING-EATING',
#        'WALKING-TEXTING', 'WALKING-DRINKING__NON-ALCOHOL_',
#        'SITTING-TOILET', 'STANDING_IN_PLACE-',
#        'STANDING_AND_MOVING-STAIRS_-_GOING_DOWN',
#        'STANDING_AND_MOVING-STAIRS_-_GOING_UP', 'STANDING_AND_MOVING-',
#        'LYING_DOWN-SLEEPING', 'WALKING-EATING',
#        'STANDING_IN_PLACE-TOILET', 'WALKING-STAIRS_-_GOING_DOWN',
#        'WALKING-STAIRS_-_GOING_UP', 'RUNNING-', 'SITTING-ON_A_BUS',
#        'SITTING-WATCHING_TV', 'SITTING-DRIVE_-_I_M_THE_DRIVER',
#        'WALKING-COOKING', 'BICYCLING-', 'STANDING_IN_PLACE-COOKING',
#        'STANDING_IN_PLACE-WASHING_DISHES', 'SITTING-READING_A_BOOK',
#        'SITTING-PLAYING_VIDEOGAMES', 'WALKING-DOING_LAUNDRY',
#        'STANDING_AND_MOVING-WASHING_DISHES',
# ...

# %%
watch_1_copy.to_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_activity/watch_1.dat',index=False)

# %% [markdown]
# ###Actividades unicas del watch_2

# %%
watch_2 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_NAN/watch_2.dat', delimiter=',')
# Out:
# <ipython-input-13-3cb6b2a4e494>:1: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   watch_2 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_NAN/watch_2.dat', delimiter=',')

# %%
watch_2
# Out:
#                         TimeStamp  X_Acc  Y_Acc   Z_Acc             Activity  \
# 0         2015-08-04 12:20:21.125   -8.0 -200.0 -1008.0              SITTING
# 1         2015-08-04 12:20:21.165  -16.0 -192.0 -1048.0              SITTING
# 2         2015-08-04 12:20:21.205  -24.0 -200.0  -992.0              SITTING
# 3         2015-08-04 12:20:21.245   -8.0 -192.0  -984.0              SITTING
# 4         2015-08-04 12:20:21.285    8.0 -208.0 -1000.0              SITTING
# ...                           ...    ...    ...     ...                  ...
# 24384233  2015-10-16 10:31:23.410 -280.0  552.0   824.0  STANDING_AND_MOVING
# 24384234  2015-10-16 10:31:23.450 -296.0  528.0   848.0  STANDING_AND_MOVING
# 24384235  2015-10-16 10:31:23.490 -288.0  528.0   840.0  STANDING_AND_MOVING
# 24384236  2015-10-16 10:31:23.530 -272.0  528.0   864.0  STANDING_AND_MOVING
# 24384237  2015-10-16 10:31:23.570 -272.0  528.0   832.0  STANDING_AND_MOVING
#
#          Activity_2 Activity_3  User
# ...

# %%
watch_2_copy = watch_2.copy()
watch_2_copy.drop(columns=['Activity_3'], inplace=True)
watch_2_copy['Activity'] = watch_2_copy['Activity'].fillna('') + '-' + watch_2_copy['Activity_2'].fillna('')
watch_2_copy.drop(columns=['Activity_2'], inplace=True)

# %%
unique_activities = watch_2_copy['Activity'].unique()
unique_activities
# Out:
# array(['SITTING-', 'WALKING-', 'SITTING-COMPUTER_WORK',
#        'STANDING_AND_MOVING-COOKING', 'SITTING-EATING',
#        'STANDING_AND_MOVING-', 'STANDING_IN_PLACE-EATING',
#        'SITTING-DRIVE_-_I_M_THE_DRIVER', 'WALKING-STAIRS_-_GOING_UP',
#        'LYING_DOWN-PLAYING_PHONE-GAMES', 'WALKING-STAIRS_-_GOING_DOWN',
#        'SITTING-IN_A_CAR', 'STANDING_IN_PLACE-', 'RUNNING-',
#        'LYING_DOWN-SLEEPING', 'STANDING_AND_MOVING-TOILET',
#        'SITTING-TOILET', 'SITTING-TEXTING',
#        'SITTING-SURFING_THE_INTERNET', 'SITTING-ON_A_BUS',
#        'STANDING_IN_PLACE-COOKING', 'SITTING-WATCHING_TV',
#        'STANDING_IN_PLACE-WASHING_DISHES', 'STANDING_AND_MOVING-DRESSING',
#        'WALKING-EATING', 'STANDING_AND_MOVING-WASHING_DISHES',
#        'SITTING-WASHING_DISHES', 'STANDING_AND_MOVING-DOING_LAUNDRY',
#        'STANDING_IN_PLACE-ON_A_BUS', 'LYING_DOWN-WATCHING_TV',
#        'LYING_DOWN-SURFING_THE_INTERNET', 'LYING_DOWN-',
# ...

# %%
watch_2_copy
# Out:
#                         TimeStamp  X_Acc  Y_Acc   Z_Acc              Activity  \
# 0         2015-08-04 12:20:21.125   -8.0 -200.0 -1008.0              SITTING-
# 1         2015-08-04 12:20:21.165  -16.0 -192.0 -1048.0              SITTING-
# 2         2015-08-04 12:20:21.205  -24.0 -200.0  -992.0              SITTING-
# 3         2015-08-04 12:20:21.245   -8.0 -192.0  -984.0              SITTING-
# 4         2015-08-04 12:20:21.285    8.0 -208.0 -1000.0              SITTING-
# ...                           ...    ...    ...     ...                   ...
# 24384233  2015-10-16 10:31:23.410 -280.0  552.0   824.0  STANDING_AND_MOVING-
# 24384234  2015-10-16 10:31:23.450 -296.0  528.0   848.0  STANDING_AND_MOVING-
# 24384235  2015-10-16 10:31:23.490 -288.0  528.0   840.0  STANDING_AND_MOVING-
# 24384236  2015-10-16 10:31:23.530 -272.0  528.0   864.0  STANDING_AND_MOVING-
# 24384237  2015-10-16 10:31:23.570 -272.0  528.0   832.0  STANDING_AND_MOVING-
#
#           User
# 0           23
# ...

# %%
watch_2_copy.to_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_activity/watch_2.dat',index=False)

# %% [markdown]
# ###Actividades unicas del watch_3

# %%
watch_3 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_NAN/watch_3.dat', delimiter=',')
# Out:
# <ipython-input-20-7c2be0011288>:1: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   watch_3 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_NAN/watch_3.dat', delimiter=',')

# %%
watch_3
# Out:
#                         TimeStamp  X_Acc  Y_Acc   Z_Acc   Activity Activity_2  \
# 0         2015-10-15 10:48:40.022  -32.0 -664.0  -776.0    SITTING        NaN
# 1         2015-10-15 10:48:40.062    8.0  -24.0 -1000.0    SITTING        NaN
# 2         2015-10-15 10:48:40.102    0.0  -16.0 -1040.0    SITTING        NaN
# 3         2015-10-15 10:48:40.142    0.0  -16.0 -1000.0    SITTING        NaN
# 4         2015-10-15 10:48:40.182    0.0   -8.0 -1000.0    SITTING        NaN
# ...                           ...    ...    ...     ...        ...        ...
# 29700247  2015-09-16 09:01:13.704 -576.0  328.0  -672.0  BICYCLING        NaN
# 29700248  2015-09-16 09:01:13.744 -576.0  384.0  -752.0  BICYCLING        NaN
# 29700249  2015-09-16 09:01:13.784 -576.0  336.0  -728.0  BICYCLING        NaN
# 29700250  2015-09-16 09:01:13.824 -568.0  400.0  -744.0  BICYCLING        NaN
# 29700251  2015-09-16 09:01:13.864 -536.0  408.0  -720.0  BICYCLING        NaN
#
#          Activity_3  User
# ...

# %%
watch_3_copy = watch_3.copy()
watch_3_copy.drop(columns=['Activity_3'], inplace=True)
watch_3_copy['Activity'] = watch_3_copy['Activity'].fillna('') + '-' + watch_3_copy['Activity_2'].fillna('')
watch_3_copy.drop(columns=['Activity_2'], inplace=True)

# %%
unique_activities = watch_3_copy['Activity'].unique()
unique_activities
# Out:
# array(['SITTING-', 'WALKING-', 'SITTING-ON_A_BUS', 'SITTING-EATING',
#        'BICYCLING-', 'SITTING-PLAYING_VIDEOGAMES',
#        'STANDING_AND_MOVING-EATING',
#        'STANDING_AND_MOVING-BATHING_-_SHOWER', 'LYING_DOWN-SLEEPING',
#        'STANDING_AND_MOVING-', 'STANDING_IN_PLACE-', 'LYING_DOWN-',
#        'STANDING_AND_MOVING-SLEEPING', 'STANDING_AND_MOVING-TOILET',
#        'STANDING_AND_MOVING-ELEVATOR', 'STANDING_AND_MOVING-COOKING',
#        'SITTING-WASHING_DISHES', 'STANDING_AND_MOVING-CLEANING',
#        'STANDING_AND_MOVING-WASHING_DISHES',
#        'SITTING-SURFING_THE_INTERNET',
#        'STANDING_AND_MOVING-DRINKING__NON-ALCOHOL_', 'RUNNING-',
#        'STANDING_AND_MOVING-TEXTING',
#        'STANDING_AND_MOVING-SURFING_THE_INTERNET', 'SITTING-TEXTING',
#        'SITTING-SLEEPING', 'WALKING-ELEVATOR',
#        'WALKING-STAIRS_-_GOING_DOWN', 'LYING_DOWN-SURFING_THE_INTERNET',
#        'LYING_DOWN-TEXTING', 'LYING_DOWN-DRINKING__NON-ALCOHOL_',
# ...

# %%
watch_3_copy.to_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_activity/watch_3.dat',index=False)

# %% [markdown]
# ###Actividades unicas en general

# %%
#####watch_3###############
array_3 = ['SITTING-', 'WALKING-', 'SITTING-ON_A_BUS', 'SITTING-EATING',
       'BICYCLING-', 'SITTING-PLAYING_VIDEOGAMES',
       'STANDING_AND_MOVING-EATING',
       'STANDING_AND_MOVING-BATHING_-_SHOWER', 'LYING_DOWN-SLEEPING',
       'STANDING_AND_MOVING-', 'STANDING_IN_PLACE-', 'LYING_DOWN-',
       'STANDING_AND_MOVING-SLEEPING', 'STANDING_AND_MOVING-TOILET',
       'STANDING_AND_MOVING-ELEVATOR', 'STANDING_AND_MOVING-COOKING',
       'SITTING-WASHING_DISHES', 'STANDING_AND_MOVING-CLEANING',
       'STANDING_AND_MOVING-WASHING_DISHES',
       'SITTING-SURFING_THE_INTERNET',
       'STANDING_AND_MOVING-DRINKING__NON-ALCOHOL_', 'RUNNING-',
       'STANDING_AND_MOVING-TEXTING',
       'STANDING_AND_MOVING-SURFING_THE_INTERNET', 'SITTING-TEXTING',
       'SITTING-SLEEPING', 'WALKING-ELEVATOR',
       'WALKING-STAIRS_-_GOING_DOWN', 'LYING_DOWN-SURFING_THE_INTERNET',
       'LYING_DOWN-TEXTING', 'LYING_DOWN-DRINKING__NON-ALCOHOL_',
       'STANDING_AND_MOVING-DRESSING', 'SITTING-COOKING',
       'SITTING-DRINKING__NON-ALCOHOL_', 'STANDING_IN_PLACE-EATING',
       'WALKING-TEXTING', 'SITTING-IN_A_CAR', 'SITTING-WATCHING_TV',
       'LYING_DOWN-WATCHING_TV', 'WALKING-TREADMILL', 'RUNNING-TREADMILL',
       'STANDING_AND_MOVING-WATCHING_TV',
       'STANDING_AND_MOVING-DOING_LAUNDRY', 'SITTING-COMPUTER_WORK',
       'LYING_DOWN-COMPUTER_WORK', 'WALKING-CLEANING',
       'STANDING_IN_PLACE-BATHING_-_SHOWER', 'WALKING-COMPUTER_WORK',
       'STANDING_IN_PLACE-COMPUTER_WORK',
       'STANDING_AND_MOVING-COMPUTER_WORK', 'WALKING-TOILET',
       'STANDING_IN_PLACE-ELEVATOR', 'STANDING_IN_PLACE-COOKING',
       'WALKING-STAIRS_-_GOING_UP', 'SITTING-DRIVE_-_I_M_THE_DRIVER',
       'STANDING_IN_PLACE-TOILET', 'LYING_DOWN-PLAYING_VIDEOGAMES',
       'WALKING-DOING_LAUNDRY', 'LYING_DOWN-EATING',
       'RUNNING-ELLIPTICAL_MACHINE', 'WALKING-COOKING', 'SITTING-TOILET',
       'STANDING_AND_MOVING-EXERCISING', 'BICYCLING-SKATEBOARDING',
       'RUNNING-EXERCISING', 'BICYCLING-EXERCISING', 'SITTING-ON_A_TRAIN',
       'STANDING_IN_PLACE-WASHING_DISHES', 'STANDING_IN_PLACE-ON_A_TRAIN',
       'LYING_DOWN-READING_A_BOOK', 'SITTING-READING_A_BOOK',
       'STANDING_IN_PLACE-YOGA', 'SITTING-YOGA',
       'STANDING_IN_PLACE-WATCHING_TV', 'WALKING-DRINKING__NON-ALCOHOL_',
       'WALKING-EATING', 'STANDING_IN_PLACE-TEXTING',
       'STANDING_IN_PLACE-DOING_LAUNDRY',
       'STANDING_IN_PLACE-DRINKING__NON-ALCOHOL_', 'SITTING-CLEANING',
       'RUNNING-PLAYING_BASEBALL', 'LYING_DOWN-TOILET',
       'SITTING-DRESSING', 'SITTING-PLAYING_PHONE-GAMES',
       'STANDING_AND_MOVING-SKATEBOARDING', 'WALKING-SKATEBOARDING',
       'STANDING_IN_PLACE-DRESSING',
       'STANDING_AND_MOVING-DRIVE_-_I_M_THE_DRIVER',
       'STANDING_IN_PLACE-SURFING_THE_INTERNET',
       'RUNNING-STAIRS_-_GOING_UP',
       'STANDING_IN_PLACE-PLAYING_VIDEOGAMES',
       'STANDING_IN_PLACE-ON_A_BUS', 'STANDING_IN_PLACE-STRETCHING',
       'WALKING-DRESSING']
############watch_1

array_1 = ['SITTING-', 'SITTING-COMPUTER_WORK', 'WALKING-',
       'STANDING_AND_MOVING-COOKING', 'LYING_DOWN-',
       'STANDING_AND_MOVING-BATHING_-_SHOWER',
       'STANDING_AND_MOVING-DRESSING', 'SITTING-EATING',
       'WALKING-TEXTING', 'WALKING-DRINKING__NON-ALCOHOL_',
       'SITTING-TOILET', 'STANDING_IN_PLACE-',
       'STANDING_AND_MOVING-STAIRS_-_GOING_DOWN',
       'STANDING_AND_MOVING-STAIRS_-_GOING_UP', 'STANDING_AND_MOVING-',
       'LYING_DOWN-SLEEPING', 'WALKING-EATING',
       'STANDING_IN_PLACE-TOILET', 'WALKING-STAIRS_-_GOING_DOWN',
       'WALKING-STAIRS_-_GOING_UP', 'RUNNING-', 'SITTING-ON_A_BUS',
       'SITTING-WATCHING_TV', 'SITTING-DRIVE_-_I_M_THE_DRIVER',
       'WALKING-COOKING', 'BICYCLING-', 'STANDING_IN_PLACE-COOKING',
       'STANDING_IN_PLACE-WASHING_DISHES', 'SITTING-READING_A_BOOK',
       'SITTING-PLAYING_VIDEOGAMES', 'WALKING-DOING_LAUNDRY',
       'STANDING_AND_MOVING-WASHING_DISHES',
       'STANDING_AND_MOVING-STRETCHING', 'SITTING-STRETCHING',
       'LYING_DOWN-SURFING_THE_INTERNET', 'SITTING-SURFING_THE_INTERNET',
       'STANDING_AND_MOVING-CLEANING', 'WALKING-CLEANING',
       'SITTING-SLEEPING', 'STANDING_IN_PLACE-SLEEPING',
       'STANDING_AND_MOVING-EATING', 'LYING_DOWN-TEXTING',
       'STANDING_AND_MOVING-SURFING_THE_INTERNET', 'SITTING-IN_A_CAR',
       'LYING_DOWN-READING_A_BOOK', 'BICYCLING-EXERCISING',
       'STANDING_IN_PLACE-BATHING_-_SHOWER', 'SITTING-TEXTING',
       'STANDING_AND_MOVING-EXERCISING', 'BICYCLING-STATIONARY_BIKE',
       'LYING_DOWN-COMPUTER_WORK', 'STANDING_IN_PLACE-DRESSING',
       'STANDING_AND_MOVING-TOILET', 'SITTING-DRINKING__NON-ALCOHOL_',
       'STANDING_IN_PLACE-DRINKING__NON-ALCOHOL_',
       'WALKING-SURFING_THE_INTERNET', 'SITTING-ON_A_TRAIN',
       'STANDING_IN_PLACE-SURFING_THE_INTERNET',
       'STANDING_IN_PLACE-EATING',
       'STANDING_AND_MOVING-DRINKING__NON-ALCOHOL_', 'WALKING-ON_A_TRAIN',
       'LYING_DOWN-DRINKING__NON-ALCOHOL_', 'SITTING-DRESSING',
       'WALKING-TOILET', 'STANDING_AND_MOVING-COMPUTER_WORK',
       'STANDING_AND_MOVING-ON_A_BUS',
       'STANDING_IN_PLACE-DRIVE_-_I_M_THE_DRIVER',
       'STANDING_IN_PLACE-ON_A_BUS',
       'STANDING_AND_MOVING-PLAYING_BASEBALL',
       'STANDING_AND_MOVING-TEXTING', 'WALKING-DRIVE_-_I_M_THE_DRIVER',
       'WALKING-COMPUTER_WORK', 'LYING_DOWN-STRETCHING',
       'WALKING-ELEVATOR', 'STANDING_IN_PLACE-STRETCHING',
       'WALKING-STRETCHING', 'SITTING-COOKING', 'SITTING-MOTORBIKE',
       'LYING_DOWN-WATCHING_TV', 'STANDING_AND_MOVING-DOING_LAUNDRY',
       'WALKING-WATCHING_TV', 'STANDING_AND_MOVING-SKATEBOARDING',
       'STANDING_AND_MOVING-WATCHING_TV', 'RUNNING-EXERCISING',
       'WALKING-EXERCISING', 'SITTING-PLAYING_PHONE-GAMES',
       'STANDING_IN_PLACE-PLAYING_PHONE-GAMES', 'WALKING-DRESSING',
       'STANDING_IN_PLACE-WATCHING_TV', 'LYING_DOWN-PLAYING_PHONE-GAMES']


######watch_2

array_2 = ['SITTING-', 'WALKING-', 'SITTING-COMPUTER_WORK',
       'STANDING_AND_MOVING-COOKING', 'SITTING-EATING',
       'STANDING_AND_MOVING-', 'STANDING_IN_PLACE-EATING',
       'SITTING-DRIVE_-_I_M_THE_DRIVER', 'WALKING-STAIRS_-_GOING_UP',
       'LYING_DOWN-PLAYING_PHONE-GAMES', 'WALKING-STAIRS_-_GOING_DOWN',
       'SITTING-IN_A_CAR', 'STANDING_IN_PLACE-', 'RUNNING-',
       'LYING_DOWN-SLEEPING', 'STANDING_AND_MOVING-TOILET',
       'SITTING-TOILET', 'SITTING-TEXTING',
       'SITTING-SURFING_THE_INTERNET', 'SITTING-ON_A_BUS',
       'STANDING_IN_PLACE-COOKING', 'SITTING-WATCHING_TV',
       'STANDING_IN_PLACE-WASHING_DISHES', 'STANDING_AND_MOVING-DRESSING',
       'WALKING-EATING', 'STANDING_AND_MOVING-WASHING_DISHES',
       'SITTING-WASHING_DISHES', 'STANDING_AND_MOVING-DOING_LAUNDRY',
       'STANDING_IN_PLACE-ON_A_BUS', 'LYING_DOWN-WATCHING_TV',
       'LYING_DOWN-SURFING_THE_INTERNET', 'LYING_DOWN-',
       'STANDING_AND_MOVING-BATHING_-_SHOWER',
       'SITTING-DRINKING__NON-ALCOHOL_', 'SITTING-SLEEPING',
       'LYING_DOWN-READING_A_BOOK',
       'STANDING_AND_MOVING-DRINKING__NON-ALCOHOL_',
       'SITTING-READING_A_BOOK', 'STANDING_IN_PLACE-BATHING_-_SHOWER',
       'WALKING-SURFING_THE_INTERNET', 'SITTING-COOKING', 'IN_A_CAR-',
       'SITTING-DANCING', 'WALKING-IN_A_CAR', 'EATING-', 'WALKING-TOILET',
       'SITTING-SMOKING', 'STANDING_IN_PLACE-DANCING',
       'SITTING-PLAYING_VIDEOGAMES', 'WALKING-TEXTING',
       'WALKING-DRINKING__NON-ALCOHOL_', 'SITTING-STRETCHING',
       'WALKING-COOKING', 'WALKING-ELEVATOR',
       'STANDING_AND_MOVING-CLEANING', 'WALKING-COMPUTER_WORK',
       'STANDING_IN_PLACE-ELEVATOR', 'STANDING_AND_MOVING-EATING',
       'STANDING_AND_MOVING-COMPUTER_WORK', 'STANDING_IN_PLACE-TEXTING',
       'LYING_DOWN-TEXTING', 'STANDING_AND_MOVING-TEXTING',
       'WALKING-ON_A_BUS', 'WALKING-EXERCISING', 'SITTING-CLEANING',
       'BICYCLING-', 'LYING_DOWN-EATING',
       'STANDING_AND_MOVING-SURFING_THE_INTERNET',
       'BICYCLING-SURFING_THE_INTERNET', 'STANDING_AND_MOVING-STRETCHING',
       'BICYCLING-EXERCISING', 'STANDING_IN_PLACE-TOILET',
       'WALKING-DRIVE_-_I_M_THE_DRIVER',
       'STANDING_IN_PLACE-DRINKING__NON-ALCOHOL_',
       'STANDING_IN_PLACE-DRESSING', 'WALKING-BATHING_-_SHOWER',
       'STANDING_AND_MOVING-PLAYING_FRISBEE',
       'STANDING_IN_PLACE-CLEANING', 'STANDING_AND_MOVING-EXERCISING']

# %%
array_1

# %%
combined_array = array_1 + array_2 + array_3

# Convierte el arreglo combinado en un conjunto para eliminar duplicados
unique_activities_set = set(combined_array)

# Convierte el conjunto nuevamente en una lista
final_array = list(unique_activities_set)

# %%
final_array
# Out:
# ['SITTING-ON_A_TRAIN',
#  'WALKING-',
#  'WALKING-DRIVE_-_I_M_THE_DRIVER',
#  'SITTING-COMPUTER_WORK',
#  'STANDING_AND_MOVING-SLEEPING',
#  'SITTING-EATING',
#  'STANDING_IN_PLACE-SURFING_THE_INTERNET',
#  'RUNNING-PLAYING_BASEBALL',
#  'STANDING_AND_MOVING-ON_A_BUS',
#  'SITTING-PLAYING_VIDEOGAMES',
#  'WALKING-SURFING_THE_INTERNET',
#  'SITTING-COOKING',
#  'STANDING_AND_MOVING-DOING_LAUNDRY',
#  'STANDING_AND_MOVING-BATHING_-_SHOWER',
#  'STANDING_IN_PLACE-TEXTING',
#  'WALKING-COMPUTER_WORK',
#  'BICYCLING-SURFING_THE_INTERNET',
#  'LYING_DOWN-SURFING_THE_INTERNET',
#  'WALKING-DRESSING',
#  'STANDING_AND_MOVING-TOILET',
#  'LYING_DOWN-TEXTING',
#  'STANDING_IN_PLACE-DANCING',
#  'SITTING-CLEANING',
#  'STANDING_IN_PLACE-DRINKING__NON-ALCOHOL_',
#  'STANDING_AND_MOVING-PLAYING_FRISBEE',
#  'WALKING-STRETCHING',
#  'SITTING-',
#  'WALKING-TREADMILL',
#  'WALKING-ON_A_TRAIN',
#  'STANDING_IN_PLACE-WATCHING_TV',
#  'WALKING-COOKING',
#  'SITTING-SLEEPING',
# ...

# %% [markdown]
# ###Preparando el watch_1

# %%
watch_1 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_activity/watch_1.dat', sep = ',')

# %%
watch_1
# Out:
#                         TimeStamp  X_Acc   Y_Acc   Z_Acc  Activity  User
# 0         2015-10-05 16:06:01.124   24.0   -48.0 -1024.0  SITTING-     1
# 1         2015-10-05 16:06:01.164   16.0   -40.0 -1048.0  SITTING-     1
# 2         2015-10-05 16:06:01.204   -8.0   -48.0 -1016.0  SITTING-     1
# 3         2015-10-05 16:06:01.244    0.0   -56.0 -1008.0  SITTING-     1
# 4         2015-10-05 16:06:01.284    0.0   -48.0 -1040.0  SITTING-     1
# ...                           ...    ...     ...     ...       ...   ...
# 30461059  2015-12-07 16:57:32.513   88.0   440.0   696.0  WALKING-    11
# 30461060  2015-12-07 16:57:32.553  -56.0   -32.0  -984.0  WALKING-    11
# 30461061  2015-12-07 16:57:32.593 -440.0   904.0   408.0  WALKING-    11
# 30461062  2015-12-07 16:57:32.633 -208.0  1472.0   944.0  WALKING-    11
# 30461063  2015-12-07 16:57:32.673 -424.0   816.0   456.0  WALKING-    11
#
# [30461064 rows x 6 columns]

# %%
watch_1.insert(0, 'Dataset', 16)
watch_1.insert(1, 'Code', 301)
watch_1.insert(2, 'Frequency', 25)
watch_1.insert(3, 'Trial', np.nan)
watch_1.insert(4, 'X_Gyro', np.nan)
watch_1.insert(5, 'Y_Gyro', np.nan)
watch_1.insert(6, 'Z_Gyro', np.nan)

# %%
watch_1
# Out:
#           Dataset  Code  Frequency  Trial  X_Gyro  Y_Gyro  Z_Gyro  \
# 0              16   301         25    NaN     NaN     NaN     NaN
# 1              16   301         25    NaN     NaN     NaN     NaN
# 2              16   301         25    NaN     NaN     NaN     NaN
# 3              16   301         25    NaN     NaN     NaN     NaN
# 4              16   301         25    NaN     NaN     NaN     NaN
# ...           ...   ...        ...    ...     ...     ...     ...
# 30461059       16   301         25    NaN     NaN     NaN     NaN
# 30461060       16   301         25    NaN     NaN     NaN     NaN
# 30461061       16   301         25    NaN     NaN     NaN     NaN
# 30461062       16   301         25    NaN     NaN     NaN     NaN
# 30461063       16   301         25    NaN     NaN     NaN     NaN
#
#                         TimeStamp  X_Acc   Y_Acc   Z_Acc  Activity  User
# 0         2015-10-05 16:06:01.124   24.0   -48.0 -1024.0  SITTING-     1
# ...

# %%
watch_1_1 = watch_1.reindex(columns=['Dataset','Activity','X_Acc','Y_Acc','Z_Acc','X_Gyro','Y_Gyro','Z_Gyro','Code','TimeStamp','Frequency','User','Trial'])

# %%
watch_1_1
# Out:
#           Dataset  Activity  X_Acc   Y_Acc   Z_Acc  X_Gyro  Y_Gyro  Z_Gyro  \
# 0              16  SITTING-   24.0   -48.0 -1024.0     NaN     NaN     NaN
# 1              16  SITTING-   16.0   -40.0 -1048.0     NaN     NaN     NaN
# 2              16  SITTING-   -8.0   -48.0 -1016.0     NaN     NaN     NaN
# 3              16  SITTING-    0.0   -56.0 -1008.0     NaN     NaN     NaN
# 4              16  SITTING-    0.0   -48.0 -1040.0     NaN     NaN     NaN
# ...           ...       ...    ...     ...     ...     ...     ...     ...
# 30461059       16  WALKING-   88.0   440.0   696.0     NaN     NaN     NaN
# 30461060       16  WALKING-  -56.0   -32.0  -984.0     NaN     NaN     NaN
# 30461061       16  WALKING- -440.0   904.0   408.0     NaN     NaN     NaN
# 30461062       16  WALKING- -208.0  1472.0   944.0     NaN     NaN     NaN
# 30461063       16  WALKING- -424.0   816.0   456.0     NaN     NaN     NaN
#
#           Code                TimeStamp  Frequency  User  Trial
# ...

# %%
def mg_to_m_s2(mg):
    return mg * 9.81 / 1000

watch_1_1['X_Acc'] = watch_1_1['X_Acc'].apply(mg_to_m_s2)
watch_1_1['Y_Acc'] = watch_1_1['Y_Acc'].apply(mg_to_m_s2)
watch_1_1['Z_Acc'] = watch_1_1['Z_Acc'].apply(mg_to_m_s2)

# %%
watch_1_1
# Out:
#           Dataset  Activity    X_Acc     Y_Acc     Z_Acc  X_Gyro  Y_Gyro  \
# 0              16  SITTING-  0.23544  -0.47088 -10.04544     NaN     NaN
# 1              16  SITTING-  0.15696  -0.39240 -10.28088     NaN     NaN
# 2              16  SITTING- -0.07848  -0.47088  -9.96696     NaN     NaN
# 3              16  SITTING-  0.00000  -0.54936  -9.88848     NaN     NaN
# 4              16  SITTING-  0.00000  -0.47088 -10.20240     NaN     NaN
# ...           ...       ...      ...       ...       ...     ...     ...
# 30461059       16  WALKING-  0.86328   4.31640   6.82776     NaN     NaN
# 30461060       16  WALKING- -0.54936  -0.31392  -9.65304     NaN     NaN
# 30461061       16  WALKING- -4.31640   8.86824   4.00248     NaN     NaN
# 30461062       16  WALKING- -2.04048  14.44032   9.26064     NaN     NaN
# 30461063       16  WALKING- -4.15944   8.00496   4.47336     NaN     NaN
#
#           Z_Gyro  Code                TimeStamp  Frequency  User  Trial
# ...

# %%
watch_1_1.to_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_FINAL/watch_1.dat',index=False)

# %% [markdown]
# ###Preparando el watch_2

# %%
watch_2 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_activity/watch_2.dat', sep = ',')

# %%
watch_2
# Out:
#                         TimeStamp  X_Acc  Y_Acc   Z_Acc              Activity  \
# 0         2015-08-04 12:20:21.125   -8.0 -200.0 -1008.0              SITTING-
# 1         2015-08-04 12:20:21.165  -16.0 -192.0 -1048.0              SITTING-
# 2         2015-08-04 12:20:21.205  -24.0 -200.0  -992.0              SITTING-
# 3         2015-08-04 12:20:21.245   -8.0 -192.0  -984.0              SITTING-
# 4         2015-08-04 12:20:21.285    8.0 -208.0 -1000.0              SITTING-
# ...                           ...    ...    ...     ...                   ...
# 24384233  2015-10-16 10:31:23.410 -280.0  552.0   824.0  STANDING_AND_MOVING-
# 24384234  2015-10-16 10:31:23.450 -296.0  528.0   848.0  STANDING_AND_MOVING-
# 24384235  2015-10-16 10:31:23.490 -288.0  528.0   840.0  STANDING_AND_MOVING-
# 24384236  2015-10-16 10:31:23.530 -272.0  528.0   864.0  STANDING_AND_MOVING-
# 24384237  2015-10-16 10:31:23.570 -272.0  528.0   832.0  STANDING_AND_MOVING-
#
#           User
# 0           23
# ...

# %%
watch_2.insert(0, 'Dataset', 16)
watch_2.insert(1, 'Code', 301)
watch_2.insert(2, 'Frequency', 25)
watch_2.insert(3, 'Trial', np.nan)
watch_2.insert(4, 'X_Gyro', np.nan)
watch_2.insert(5, 'Y_Gyro', np.nan)
watch_2.insert(6, 'Z_Gyro', np.nan)

# %%
watch_2_2 = watch_2.reindex(columns=['Dataset','Activity','X_Acc','Y_Acc','Z_Acc','X_Gyro','Y_Gyro','Z_Gyro','Code','TimeStamp','Frequency','User','Trial'])

# %%
def mg_to_m_s2(mg):
    return mg * 9.81 / 1000

watch_2_2['X_Acc'] = watch_2_2['X_Acc'].apply(mg_to_m_s2)
watch_2_2['Y_Acc'] = watch_2_2['Y_Acc'].apply(mg_to_m_s2)
watch_2_2['Z_Acc'] = watch_2_2['Z_Acc'].apply(mg_to_m_s2)

# %%
watch_2_2
# Out:
#           Dataset              Activity    X_Acc    Y_Acc     Z_Acc  X_Gyro  \
# 0              16              SITTING- -0.07848 -1.96200  -9.88848     NaN
# 1              16              SITTING- -0.15696 -1.88352 -10.28088     NaN
# 2              16              SITTING- -0.23544 -1.96200  -9.73152     NaN
# 3              16              SITTING- -0.07848 -1.88352  -9.65304     NaN
# 4              16              SITTING-  0.07848 -2.04048  -9.81000     NaN
# ...           ...                   ...      ...      ...       ...     ...
# 24384233       16  STANDING_AND_MOVING- -2.74680  5.41512   8.08344     NaN
# 24384234       16  STANDING_AND_MOVING- -2.90376  5.17968   8.31888     NaN
# 24384235       16  STANDING_AND_MOVING- -2.82528  5.17968   8.24040     NaN
# 24384236       16  STANDING_AND_MOVING- -2.66832  5.17968   8.47584     NaN
# 24384237       16  STANDING_AND_MOVING- -2.66832  5.17968   8.16192     NaN
#
# ...

# %%
watch_2_2.to_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_FINAL/watch_2.dat',index=False)

# %% [markdown]
# ###Preparando el watch_3

# %%
watch_3 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_activity/watch_3.dat', sep = ',')

# %%
watch_3
# Out:
#                         TimeStamp  X_Acc  Y_Acc   Z_Acc    Activity  User
# 0         2015-10-15 10:48:40.022  -32.0 -664.0  -776.0    SITTING-    39
# 1         2015-10-15 10:48:40.062    8.0  -24.0 -1000.0    SITTING-    39
# 2         2015-10-15 10:48:40.102    0.0  -16.0 -1040.0    SITTING-    39
# 3         2015-10-15 10:48:40.142    0.0  -16.0 -1000.0    SITTING-    39
# 4         2015-10-15 10:48:40.182    0.0   -8.0 -1000.0    SITTING-    39
# ...                           ...    ...    ...     ...         ...   ...
# 29700247  2015-09-16 09:01:13.704 -576.0  328.0  -672.0  BICYCLING-    57
# 29700248  2015-09-16 09:01:13.744 -576.0  384.0  -752.0  BICYCLING-    57
# 29700249  2015-09-16 09:01:13.784 -576.0  336.0  -728.0  BICYCLING-    57
# 29700250  2015-09-16 09:01:13.824 -568.0  400.0  -744.0  BICYCLING-    57
# 29700251  2015-09-16 09:01:13.864 -536.0  408.0  -720.0  BICYCLING-    57
#
# [29700252 rows x 6 columns]

# %%
watch_3.insert(0, 'Dataset', 16)
watch_3.insert(1, 'Code', 301)
watch_3.insert(2, 'Frequency', 25)
watch_3.insert(3, 'Trial', np.nan)
watch_3.insert(4, 'X_Gyro', np.nan)
watch_3.insert(5, 'Y_Gyro', np.nan)
watch_3.insert(6, 'Z_Gyro', np.nan)

# %%
watch_3_3 = watch_3.reindex(columns=['Dataset','Activity','X_Acc','Y_Acc','Z_Acc','X_Gyro','Y_Gyro','Z_Gyro','Code','TimeStamp','Frequency','User','Trial'])

# %%
def mg_to_m_s2(mg):
    return mg * 9.81 / 1000

watch_3_3['X_Acc'] = watch_3_3['X_Acc'].apply(mg_to_m_s2)
watch_3_3['Y_Acc'] = watch_3_3['Y_Acc'].apply(mg_to_m_s2)
watch_3_3['Z_Acc'] = watch_3_3['Z_Acc'].apply(mg_to_m_s2)

# %%
watch_3_3
# Out:
#           Dataset    Activity    X_Acc    Y_Acc     Z_Acc  X_Gyro  Y_Gyro  \
# 0              16    SITTING- -0.31392 -6.51384  -7.61256     NaN     NaN
# 1              16    SITTING-  0.07848 -0.23544  -9.81000     NaN     NaN
# 2              16    SITTING-  0.00000 -0.15696 -10.20240     NaN     NaN
# 3              16    SITTING-  0.00000 -0.15696  -9.81000     NaN     NaN
# 4              16    SITTING-  0.00000 -0.07848  -9.81000     NaN     NaN
# ...           ...         ...      ...      ...       ...     ...     ...
# 29700247       16  BICYCLING- -5.65056  3.21768  -6.59232     NaN     NaN
# 29700248       16  BICYCLING- -5.65056  3.76704  -7.37712     NaN     NaN
# 29700249       16  BICYCLING- -5.65056  3.29616  -7.14168     NaN     NaN
# 29700250       16  BICYCLING- -5.57208  3.92400  -7.29864     NaN     NaN
# 29700251       16  BICYCLING- -5.25816  4.00248  -7.06320     NaN     NaN
#
#           Z_Gyro  Code                TimeStamp  Frequency  User  Trial
# ...

# %%
watch_3_3.to_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_FINAL/watch_3.dat',index=False)

# %% [markdown]
# ##Actividades

# %% [markdown]
# ###Actividades del watch 1

# %%
w1 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_FINAL/watch_1.dat')

# %%
w1
# Out:
#           Dataset  Activity  X_Acc  Y_Acc  Z_Acc  X_Gyro  Y_Gyro  Z_Gyro  \
# 0              16  SITTING-   0.24  -0.47 -10.05     NaN     NaN     NaN
# 1              16  SITTING-   0.16  -0.39 -10.28     NaN     NaN     NaN
# 2              16  SITTING-  -0.08  -0.47  -9.97     NaN     NaN     NaN
# 3              16  SITTING-   0.00  -0.55  -9.89     NaN     NaN     NaN
# 4              16  SITTING-   0.00  -0.47 -10.20     NaN     NaN     NaN
# ...           ...       ...    ...    ...    ...     ...     ...     ...
# 30461059       16  WALKING-   0.86   4.32   6.83     NaN     NaN     NaN
# 30461060       16  WALKING-  -0.55  -0.31  -9.65     NaN     NaN     NaN
# 30461061       16  WALKING-  -4.32   8.87   4.00     NaN     NaN     NaN
# 30461062       16  WALKING-  -2.04  14.44   9.26     NaN     NaN     NaN
# 30461063       16  WALKING-  -4.16   8.00   4.47     NaN     NaN     NaN
#
#           Code                TimeStamp  Frequency  User  Trial
# ...

# %%
mapping = {
    'SITTING-ON_A_TRAIN':65,
 'WALKING-':6,
 'WALKING-DRIVE_-_I_M_THE_DRIVER':100,
 'SITTING-COMPUTER_WORK':66,
 'STANDING_AND_MOVING-SLEEPING':100,
 'SITTING-EATING':61,
 'STANDING_IN_PLACE-SURFING_THE_INTERNET':62,
 'RUNNING-PLAYING_BASEBALL':63,
 'STANDING_AND_MOVING-ON_A_BUS':64,
 'SITTING-PLAYING_VIDEOGAMES':91,
 'WALKING-SURFING_THE_INTERNET':71,
 'SITTING-COOKING':67,
 'STANDING_AND_MOVING-DOING_LAUNDRY':69,
 'STANDING_AND_MOVING-BATHING_-_SHOWER':70,
 'STANDING_IN_PLACE-TEXTING':62,
 'WALKING-COMPUTER_WORK':100,
 'BICYCLING-SURFING_THE_INTERNET':100,
 'LYING_DOWN-SURFING_THE_INTERNET':72,
 'WALKING-DRESSING':73,
 'STANDING_AND_MOVING-TOILET':100,
 'LYING_DOWN-TEXTING':72,
 'STANDING_IN_PLACE-DANCING':74,
 'SITTING-CLEANING':75,
 'STANDING_IN_PLACE-DRINKING__NON-ALCOHOL_':46,
 'STANDING_AND_MOVING-PLAYING_FRISBEE':76,
 'WALKING-STRETCHING':77,
 'SITTING-':16,
 'WALKING-TREADMILL':51,
 'WALKING-ON_A_TRAIN':65,
 'STANDING_IN_PLACE-WATCHING_TV':17,
 'WALKING-COOKING':67,
 'SITTING-SLEEPING':16,
 'STANDING_IN_PLACE-WASHING_DISHES':17,
 'STANDING_AND_MOVING-':68,
 'STANDING_AND_MOVING-ELEVATOR':50,
 'LYING_DOWN-STRETCHING':77,
 'RUNNING-TREADMILL':32,
 'STANDING_IN_PLACE-ELEVATOR':49,
 'SITTING-TEXTING':84,
 'STANDING_AND_MOVING-STAIRS_-_GOING_UP':13,
 'STANDING_AND_MOVING-WATCHING_TV':68,
 'WALKING-EATING':61,
 'LYING_DOWN-PLAYING_PHONE-GAMES':72,
 'STANDING_IN_PLACE-DRESSING':73,
 'SITTING-READING_A_BOOK':16,
 'STANDING_IN_PLACE-DRIVE_-_I_M_THE_DRIVER':100,
 'STANDING_IN_PLACE-PLAYING_PHONE-GAMES':62,
 'LYING_DOWN-SLEEPING':18,
 'LYING_DOWN-PLAYING_VIDEOGAMES':91,
 'WALKING-STAIRS_-_GOING_DOWN':14,
 'STANDING_IN_PLACE-CLEANING':75,
 'SITTING-SURFING_THE_INTERNET':16,
 'RUNNING-ELLIPTICAL_MACHINE':55,
 'SITTING-ON_A_BUS':64,
 'SITTING-YOGA':78,
 'STANDING_AND_MOVING-DRESSING':73,
 'WALKING-STAIRS_-_GOING_UP':13,
 'WALKING-SKATEBOARDING':79,
 'LYING_DOWN-WATCHING_TV':18,
 'SITTING-DRESSING':73,
 'LYING_DOWN-COMPUTER_WORK':66,
 'SITTING-TOILET':80,
 'LYING_DOWN-EATING':61,
 'SITTING-SMOKING':81,
 'WALKING-WATCHING_TV':6,
 'WALKING-ELEVATOR':50,
 'STANDING_AND_MOVING-DRIVE_-_I_M_THE_DRIVER':100,
 'STANDING_IN_PLACE-DOING_LAUNDRY':69,
 'SITTING-PLAYING_PHONE-GAMES':84,
 'IN_A_CAR-':100,
 'STANDING_AND_MOVING-PLAYING_BASEBALL':82,
 'SITTING-MOTORBIKE':100,
 'STANDING_AND_MOVING-EXERCISING':83,
 'STANDING_AND_MOVING-COOKING':67,
 'WALKING-TEXTING':71,
 'BICYCLING-':24,
 'STANDING_IN_PLACE-COOKING':67,
 'STANDING_IN_PLACE-STRETCHING':77,
 'LYING_DOWN-TOILET':100,
 'SITTING-DRIVE_-_I_M_THE_DRIVER':12,
 'STANDING_AND_MOVING-STAIRS_-_GOING_DOWN':14,
 'STANDING_AND_MOVING-CLEANING':75,
 'LYING_DOWN-READING_A_BOOK':18,
 'WALKING-ON_A_BUS':64,
 'STANDING_IN_PLACE-COMPUTER_WORK':66,
 'STANDING_AND_MOVING-TEXTING':85,
 'WALKING-DOING_LAUNDRY':69,
 'STANDING_AND_MOVING-WASHING_DISHES':30,
 'STANDING_AND_MOVING-EATING':61,
 'STANDING_IN_PLACE-ON_A_TRAIN':65,
 'STANDING_IN_PLACE-BATHING_-_SHOWER':70,
 'STANDING_IN_PLACE-':17,
 'STANDING_IN_PLACE-TOILET':86,
 'STANDING_AND_MOVING-STRETCHING':77,
 'BICYCLING-EXERCISING':24,
 'BICYCLING-STATIONARY_BIKE':56,
 'RUNNING-EXERCISING':9,
 'STANDING_IN_PLACE-YOGA':78,
 'STANDING_IN_PLACE-ON_A_BUS':64,
 'STANDING_AND_MOVING-SKATEBOARDING':87,
 'SITTING-WATCHING_TV':16,
 'STANDING_AND_MOVING-COMPUTER_WORK':66,
 'LYING_DOWN-':18,
 'STANDING_IN_PLACE-EATING':61,
 'RUNNING-STAIRS_-_GOING_UP':88,
 'WALKING-IN_A_CAR':100,
 'SITTING-IN_A_CAR':100,
 'SITTING-DRINKING__NON-ALCOHOL_':61,
 'STANDING_AND_MOVING-SURFING_THE_INTERNET':85,
 'LYING_DOWN-DRINKING__NON-ALCOHOL_':61,
 'WALKING-TOILET':100,
 'SITTING-DANCING':100,
 'WALKING-CLEANING':75,
 'STANDING_IN_PLACE-SLEEPING':100,
 'SITTING-WASHING_DISHES':30,
 'EATING-':61,
 'WALKING-DRINKING__NON-ALCOHOL_':61,
 'WALKING-BATHING_-_SHOWER':100,
 'WALKING-EXERCISING':6,
 'STANDING_AND_MOVING-DRINKING__NON-ALCOHOL_':61,
 'RUNNING-':9,
 'SITTING-STRETCHING':77,
 'STANDING_IN_PLACE-PLAYING_VIDEOGAMES':91,
 'BICYCLING-SKATEBOARDING':100,
    'STANDING_AND_MOVING-IN_A_CAR':100
}

data = w1.copy()

data['Activity'] = data['Activity'].map(mapping)
data = data.reset_index(drop=True)

# %% [markdown]
# Asignamos el valor de 100 a las actividades que consideramos borrar para facilitar el proceso

# %%
data = data[data['Activity'] != 100]
data = data.reset_index(drop=True)

# %%
data
# Out:
#           Dataset  Activity  X_Acc  Y_Acc  Z_Acc  X_Gyro  Y_Gyro  Z_Gyro  \
# 0              16        16   0.24  -0.47 -10.05     NaN     NaN     NaN
# 1              16        16   0.16  -0.39 -10.28     NaN     NaN     NaN
# 2              16        16  -0.08  -0.47  -9.97     NaN     NaN     NaN
# 3              16        16   0.00  -0.55  -9.89     NaN     NaN     NaN
# 4              16        16   0.00  -0.47 -10.20     NaN     NaN     NaN
# ...           ...       ...    ...    ...    ...     ...     ...     ...
# 30202209       16         6   0.86   4.32   6.83     NaN     NaN     NaN
# 30202210       16         6  -0.55  -0.31  -9.65     NaN     NaN     NaN
# 30202211       16         6  -4.32   8.87   4.00     NaN     NaN     NaN
# 30202212       16         6  -2.04  14.44   9.26     NaN     NaN     NaN
# 30202213       16         6  -4.16   8.00   4.47     NaN     NaN     NaN
#
#           Code                TimeStamp  Frequency  User  Trial
# ...

# %% [markdown]
# ###Actividades del watch 2

# %%
w2 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_FINAL/watch_2.dat')

# %%
w2
# Out:
#           Dataset              Activity    X_Acc    Y_Acc     Z_Acc  X_Gyro  \
# 0              16              SITTING- -0.07848 -1.96200  -9.88848     NaN
# 1              16              SITTING- -0.15696 -1.88352 -10.28088     NaN
# 2              16              SITTING- -0.23544 -1.96200  -9.73152     NaN
# 3              16              SITTING- -0.07848 -1.88352  -9.65304     NaN
# 4              16              SITTING-  0.07848 -2.04048  -9.81000     NaN
# ...           ...                   ...      ...      ...       ...     ...
# 24384233       16  STANDING_AND_MOVING- -2.74680  5.41512   8.08344     NaN
# 24384234       16  STANDING_AND_MOVING- -2.90376  5.17968   8.31888     NaN
# 24384235       16  STANDING_AND_MOVING- -2.82528  5.17968   8.24040     NaN
# 24384236       16  STANDING_AND_MOVING- -2.66832  5.17968   8.47584     NaN
# 24384237       16  STANDING_AND_MOVING- -2.66832  5.17968   8.16192     NaN
#
# ...

# %%
mapping = {
    'SITTING-ON_A_TRAIN':65,
 'WALKING-':6,
 'WALKING-DRIVE_-_I_M_THE_DRIVER':100,
 'SITTING-COMPUTER_WORK':66,
 'STANDING_AND_MOVING-SLEEPING':100,
 'SITTING-EATING':61,
 'STANDING_IN_PLACE-SURFING_THE_INTERNET':62,
 'RUNNING-PLAYING_BASEBALL':63,
 'STANDING_AND_MOVING-ON_A_BUS':64,
 'SITTING-PLAYING_VIDEOGAMES':91,
 'WALKING-SURFING_THE_INTERNET':71,
 'SITTING-COOKING':67,
 'STANDING_AND_MOVING-DOING_LAUNDRY':69,
 'STANDING_AND_MOVING-BATHING_-_SHOWER':70,
 'STANDING_IN_PLACE-TEXTING':62,
 'WALKING-COMPUTER_WORK':100,
 'BICYCLING-SURFING_THE_INTERNET':100,
 'LYING_DOWN-SURFING_THE_INTERNET':72,
 'WALKING-DRESSING':73,
 'STANDING_AND_MOVING-TOILET':100,
 'LYING_DOWN-TEXTING':72,
 'STANDING_IN_PLACE-DANCING':74,
 'SITTING-CLEANING':75,
 'STANDING_IN_PLACE-DRINKING__NON-ALCOHOL_':46,
 'STANDING_AND_MOVING-PLAYING_FRISBEE':76,
 'WALKING-STRETCHING':77,
 'SITTING-':16,
 'WALKING-TREADMILL':51,
 'WALKING-ON_A_TRAIN':65,
 'STANDING_IN_PLACE-WATCHING_TV':17,
 'WALKING-COOKING':67,
 'SITTING-SLEEPING':16,
 'STANDING_IN_PLACE-WASHING_DISHES':17,
 'STANDING_AND_MOVING-':68,
 'STANDING_AND_MOVING-ELEVATOR':50,
 'LYING_DOWN-STRETCHING':77,
 'RUNNING-TREADMILL':32,
 'STANDING_IN_PLACE-ELEVATOR':49,
 'SITTING-TEXTING':84,
 'STANDING_AND_MOVING-STAIRS_-_GOING_UP':13,
 'STANDING_AND_MOVING-WATCHING_TV':68,
 'WALKING-EATING':61,
 'LYING_DOWN-PLAYING_PHONE-GAMES':72,
 'STANDING_IN_PLACE-DRESSING':73,
 'SITTING-READING_A_BOOK':16,
 'STANDING_IN_PLACE-DRIVE_-_I_M_THE_DRIVER':100,
 'STANDING_IN_PLACE-PLAYING_PHONE-GAMES':62,
 'LYING_DOWN-SLEEPING':18,
 'LYING_DOWN-PLAYING_VIDEOGAMES':91,
 'WALKING-STAIRS_-_GOING_DOWN':14,
 'STANDING_IN_PLACE-CLEANING':75,
 'SITTING-SURFING_THE_INTERNET':16,
 'RUNNING-ELLIPTICAL_MACHINE':55,
 'SITTING-ON_A_BUS':64,
 'SITTING-YOGA':78,
 'STANDING_AND_MOVING-DRESSING':73,
 'WALKING-STAIRS_-_GOING_UP':13,
 'WALKING-SKATEBOARDING':79,
 'LYING_DOWN-WATCHING_TV':18,
 'SITTING-DRESSING':73,
 'LYING_DOWN-COMPUTER_WORK':66,
 'SITTING-TOILET':80,
 'LYING_DOWN-EATING':61,
 'SITTING-SMOKING':81,
 'WALKING-WATCHING_TV':6,
 'WALKING-ELEVATOR':50,
 'STANDING_AND_MOVING-DRIVE_-_I_M_THE_DRIVER':100,
 'STANDING_IN_PLACE-DOING_LAUNDRY':69,
 'SITTING-PLAYING_PHONE-GAMES':84,
 'IN_A_CAR-':100,
 'STANDING_AND_MOVING-PLAYING_BASEBALL':82,
 'SITTING-MOTORBIKE':100,
 'STANDING_AND_MOVING-EXERCISING':83,
 'STANDING_AND_MOVING-COOKING':67,
 'WALKING-TEXTING':71,
 'BICYCLING-':24,
 'STANDING_IN_PLACE-COOKING':67,
 'STANDING_IN_PLACE-STRETCHING':77,
 'LYING_DOWN-TOILET':100,
 'SITTING-DRIVE_-_I_M_THE_DRIVER':12,
 'STANDING_AND_MOVING-STAIRS_-_GOING_DOWN':14,
 'STANDING_AND_MOVING-CLEANING':75,
 'LYING_DOWN-READING_A_BOOK':18,
 'WALKING-ON_A_BUS':64,
 'STANDING_IN_PLACE-COMPUTER_WORK':66,
 'STANDING_AND_MOVING-TEXTING':85,
 'WALKING-DOING_LAUNDRY':69,
 'STANDING_AND_MOVING-WASHING_DISHES':30,
 'STANDING_AND_MOVING-EATING':61,
 'STANDING_IN_PLACE-ON_A_TRAIN':65,
 'STANDING_IN_PLACE-BATHING_-_SHOWER':70,
 'STANDING_IN_PLACE-':17,
 'STANDING_IN_PLACE-TOILET':86,
 'STANDING_AND_MOVING-STRETCHING':77,
 'BICYCLING-EXERCISING':24,
 'BICYCLING-STATIONARY_BIKE':56,
 'RUNNING-EXERCISING':9,
 'STANDING_IN_PLACE-YOGA':78,
 'STANDING_IN_PLACE-ON_A_BUS':64,
 'STANDING_AND_MOVING-SKATEBOARDING':87,
 'SITTING-WATCHING_TV':16,
 'STANDING_AND_MOVING-COMPUTER_WORK':66,
 'LYING_DOWN-':18,
 'STANDING_IN_PLACE-EATING':61,
 'RUNNING-STAIRS_-_GOING_UP':88,
 'WALKING-IN_A_CAR':100,
 'SITTING-IN_A_CAR':100,
 'SITTING-DRINKING__NON-ALCOHOL_':61,
 'STANDING_AND_MOVING-SURFING_THE_INTERNET':85,
 'LYING_DOWN-DRINKING__NON-ALCOHOL_':61,
 'WALKING-TOILET':100,
 'SITTING-DANCING':100,
 'WALKING-CLEANING':75,
 'STANDING_IN_PLACE-SLEEPING':100,
 'SITTING-WASHING_DISHES':30,
 'EATING-':61,
 'WALKING-DRINKING__NON-ALCOHOL_':61,
 'WALKING-BATHING_-_SHOWER':100,
 'WALKING-EXERCISING':6,
 'STANDING_AND_MOVING-DRINKING__NON-ALCOHOL_':61,
 'RUNNING-':9,
 'SITTING-STRETCHING':77,
 'STANDING_IN_PLACE-PLAYING_VIDEOGAMES':91,
 'BICYCLING-SKATEBOARDING':100,
    'STANDING_AND_MOVING-IN_A_CAR':100
}

data2 = w2.copy()

data2['Activity'] = data2['Activity'].map(mapping)
data2 = data2.reset_index(drop=True)

# %%
data2 = data2[data2['Activity'] != 100]
data2 = data2.reset_index(drop=True)

# %%
data2
# Out:
#           Dataset  Activity    X_Acc    Y_Acc     Z_Acc  X_Gyro  Y_Gyro  \
# 0              16        16 -0.07848 -1.96200  -9.88848     NaN     NaN
# 1              16        16 -0.15696 -1.88352 -10.28088     NaN     NaN
# 2              16        16 -0.23544 -1.96200  -9.73152     NaN     NaN
# 3              16        16 -0.07848 -1.88352  -9.65304     NaN     NaN
# 4              16        16  0.07848 -2.04048  -9.81000     NaN     NaN
# ...           ...       ...      ...      ...       ...     ...     ...
# 24035233       16        68 -2.74680  5.41512   8.08344     NaN     NaN
# 24035234       16        68 -2.90376  5.17968   8.31888     NaN     NaN
# 24035235       16        68 -2.82528  5.17968   8.24040     NaN     NaN
# 24035236       16        68 -2.66832  5.17968   8.47584     NaN     NaN
# 24035237       16        68 -2.66832  5.17968   8.16192     NaN     NaN
#
#           Z_Gyro  Code                TimeStamp  Frequency  User  Trial
# ...

# %% [markdown]
# ###Actividades del watch 3

# %%
w3 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/watch_FINAL/watch_3.dat')

# %%
w3
# Out:
#           Dataset    Activity    X_Acc    Y_Acc     Z_Acc  X_Gyro  Y_Gyro  \
# 0              16    SITTING- -0.31392 -6.51384  -7.61256     NaN     NaN
# 1              16    SITTING-  0.07848 -0.23544  -9.81000     NaN     NaN
# 2              16    SITTING-  0.00000 -0.15696 -10.20240     NaN     NaN
# 3              16    SITTING-  0.00000 -0.15696  -9.81000     NaN     NaN
# 4              16    SITTING-  0.00000 -0.07848  -9.81000     NaN     NaN
# ...           ...         ...      ...      ...       ...     ...     ...
# 29700247       16  BICYCLING- -5.65056  3.21768  -6.59232     NaN     NaN
# 29700248       16  BICYCLING- -5.65056  3.76704  -7.37712     NaN     NaN
# 29700249       16  BICYCLING- -5.65056  3.29616  -7.14168     NaN     NaN
# 29700250       16  BICYCLING- -5.57208  3.92400  -7.29864     NaN     NaN
# 29700251       16  BICYCLING- -5.25816  4.00248  -7.06320     NaN     NaN
#
#           Z_Gyro  Code                TimeStamp  Frequency  User  Trial
# ...

# %%
data3 = w3.copy()

data3['Activity'] = data3['Activity'].map(mapping)
data3 = data3.reset_index(drop=True)

# %%
data3 = data3[data3['Activity'] != 100]
data3 = data3.reset_index(drop=True)

# %%
data3
# Out:
#           Dataset  Activity    X_Acc    Y_Acc     Z_Acc  X_Gyro  Y_Gyro  \
# 0              16        16 -0.31392 -6.51384  -7.61256     NaN     NaN
# 1              16        16  0.07848 -0.23544  -9.81000     NaN     NaN
# 2              16        16  0.00000 -0.15696 -10.20240     NaN     NaN
# 3              16        16  0.00000 -0.15696  -9.81000     NaN     NaN
# 4              16        16  0.00000 -0.07848  -9.81000     NaN     NaN
# ...           ...       ...      ...      ...       ...     ...     ...
# 29380247       16        24 -5.65056  3.21768  -6.59232     NaN     NaN
# 29380248       16        24 -5.65056  3.76704  -7.37712     NaN     NaN
# 29380249       16        24 -5.65056  3.29616  -7.14168     NaN     NaN
# 29380250       16        24 -5.57208  3.92400  -7.29864     NaN     NaN
# 29380251       16        24 -5.25816  4.00248  -7.06320     NaN     NaN
#
#           Z_Gyro  Code                TimeStamp  Frequency  User  Trial
# ...

# %% [markdown]
# ##Resampling

# %% [markdown]
# ###Resampling del watch 1

# %%
final1 = resample_dataframe(data)

# %%
final1
# Out:
#           Dataset  Activity  X_Acc  Y_Acc  Z_Acc  X_Gyro  Y_Gyro  Z_Gyro  \
# 0              16        16   0.24  -0.47 -10.05     NaN     NaN     NaN
# 1              16        16   0.24  -0.47 -10.05     NaN     NaN     NaN
# 2              16        16   0.16  -0.39 -10.28     NaN     NaN     NaN
# 3              16        16   0.16  -0.39 -10.28     NaN     NaN     NaN
# 4              16        16  -0.08  -0.47  -9.97     NaN     NaN     NaN
# ...           ...       ...    ...    ...    ...     ...     ...     ...
# 60404423       16        61  -7.61   6.12  -0.16     NaN     NaN     NaN
# 60404424       16        61  -7.69   6.36   0.31     NaN     NaN     NaN
# 60404425       16        61  -7.69   6.36   0.31     NaN     NaN     NaN
# 60404426       16        61  -7.93   6.36   0.16     NaN     NaN     NaN
# 60404427       16        61  -7.93   6.36   0.16     NaN     NaN     NaN
#
#           Code                TimeStamp  Frequency  User  Trial
# ...

# %%
final1.to_csv('/content/drive/MyDrive/TESIS_DATASET/Datasets definitivos_CSV/dataset16_watch_1.csv', index=False)

# %% [markdown]
# ###Resampling del watch 2

# %%
df = resample_dataframe(data2)

# %%
df
# Out:
#           Dataset  Activity    X_Acc     Y_Acc     Z_Acc  X_Gyro  Y_Gyro  \
# 0              16        16 -0.15696   0.15696  -9.96696     NaN     NaN
# 1              16        16 -0.15696   0.15696  -9.96696     NaN     NaN
# 2              16        16  0.00000   0.07848  -9.49608     NaN     NaN
# 3              16        16  0.00000   0.07848  -9.49608     NaN     NaN
# 4              16        16 -0.07848   0.07848 -10.04544     NaN     NaN
# ...           ...       ...      ...       ...       ...     ...     ...
# 48070471       16         6  7.06320   6.43536   3.84552     NaN     NaN
# 48070472       16         6  6.98472   8.31888   2.66832     NaN     NaN
# 48070473       16         6  6.98472   8.31888   2.66832     NaN     NaN
# 48070474       16         6  9.41760  11.61504   5.88600     NaN     NaN
# 48070475       16         6  9.41760  11.61504   5.88600     NaN     NaN
#
#           Z_Gyro  Code                TimeStamp  Frequency  User  Trial
# ...

# %%
df.to_csv('/content/drive/MyDrive/TESIS_DATASET/Datasets definitivos_CSV/dataset16_watch_2.csv', index=False)

# %% [markdown]
# ###Resampling del watch 3

# %%
df3 = resample_dataframe(data3)

# %%
df3
# Out:
#           Dataset  Activity    X_Acc    Y_Acc    Z_Acc  X_Gyro  Y_Gyro  \
# 0              16        16 -0.15696  0.00000 -9.57456     NaN     NaN
# 1              16        16 -0.15696  0.00000 -9.57456     NaN     NaN
# 2              16        16 -3.45312 -0.15696 -9.10368     NaN     NaN
# 3              16        16 -3.45312 -0.15696 -9.10368     NaN     NaN
# 4              16        16 -3.45312  0.07848 -9.41760     NaN     NaN
# ...           ...       ...      ...      ...      ...     ...     ...
# 58760499       16        24 -5.65056  3.29616 -7.14168     NaN     NaN
# 58760500       16        24 -5.57208  3.92400 -7.29864     NaN     NaN
# 58760501       16        24 -5.57208  3.92400 -7.29864     NaN     NaN
# 58760502       16        24 -5.25816  4.00248 -7.06320     NaN     NaN
# 58760503       16        24 -5.25816  4.00248 -7.06320     NaN     NaN
#
#           Z_Gyro  Code                TimeStamp  Frequency  User  Trial
# ...

# %%
df3.to_csv('/content/drive/MyDrive/TESIS_DATASET/Datasets definitivos_CSV/dataset16_watch_3.csv', index=False)

# %% [markdown]
# ##Describe

# %% [markdown]
# ###Describe del watch 1

# %% [markdown]
# ####Después

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

final.describe()
# Out:
#           Dataset    Activity       X_Acc       Y_Acc       Z_Acc  X_Gyro  \
# count 60404428.00 60404428.00 60404428.00 60404428.00 60404428.00    0.00
# mean        16.00       32.27       -0.16        3.53       -3.04     NaN
# std          0.00       25.00        5.47        4.54        5.60     NaN
# min         16.00        6.00      -39.55      -36.26      -40.02     NaN
# 25%         16.00       16.00       -3.77        0.24       -7.93     NaN
# 50%         16.00       18.00       -0.16        3.85       -3.61     NaN
# 75%         16.00       66.00        2.83        7.22        0.24     NaN
# max         16.00       91.00       39.95       39.55       40.02     NaN
#
#        Y_Gyro  Z_Gyro        Code   Frequency        User  Trial
# count    0.00    0.00 60404428.00 60404428.00 60404428.00   0.00
# mean      NaN     NaN      301.00       50.00       10.36    NaN
# std       NaN     NaN        0.00        0.00        4.75    NaN
# ...

# %% [markdown]
# ####Antes

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

data.describe()
# Out:
#           Dataset    Activity       X_Acc       Y_Acc       Z_Acc  X_Gyro  \
# count 30202214.00 30202214.00 30202214.00 30202214.00 30202214.00    0.00
# mean        16.00       32.27       -0.16        3.53       -3.04     NaN
# std          0.00       25.00        5.47        4.54        5.61     NaN
# min         16.00        6.00      -39.55      -36.26      -40.02     NaN
# 25%         16.00       16.00       -3.77        0.24       -7.93     NaN
# 50%         16.00       18.00       -0.16        3.85       -3.61     NaN
# 75%         16.00       66.00        2.83        7.22        0.24     NaN
# max         16.00       91.00       39.95       39.55       40.02     NaN
#
#        Y_Gyro  Z_Gyro        Code   Frequency        User  Trial
# count    0.00    0.00 30202214.00 30202214.00 30202214.00   0.00
# mean      NaN     NaN      301.00       25.00       10.36    NaN
# std       NaN     NaN        0.00        0.00        4.75    NaN
# ...

# %% [markdown]
# ###Describe del watch 2

# %% [markdown]
# ####Después

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

df.describe()
# Out:
#           Dataset    Activity       X_Acc       Y_Acc       Z_Acc  X_Gyro  \
# count 48070476.00 48070476.00 48070476.00 48070476.00 48070476.00    0.00
# mean        16.00       31.89       -0.46        3.22       -2.05     NaN
# std          0.00       23.93        5.48        4.75        6.00     NaN
# min         16.00        6.00      -39.16      -39.16      -40.02     NaN
# 25%         16.00       16.00       -4.16       -0.08       -7.46     NaN
# 50%         16.00       18.00       -0.31        3.45       -2.12     NaN
# 75%         16.00       66.00        2.35        7.30        2.12     NaN
# max         16.00       91.00       40.02       39.16       40.02     NaN
#
#        Y_Gyro  Z_Gyro        Code   Frequency        User  Trial
# count    0.00    0.00 48070476.00 48070476.00 48070476.00   0.00
# mean      NaN     NaN      301.00       50.00       27.79    NaN
# std       NaN     NaN        0.00        0.00        5.93    NaN
# ...

# %% [markdown]
# ####Antes

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

data2.describe()
# Out:
#           Dataset    Activity       X_Acc       Y_Acc       Z_Acc  X_Gyro  \
# count 24035238.00 24035238.00 24035238.00 24035238.00 24035238.00    0.00
# mean        16.00       31.88       -0.46        3.22       -2.05     NaN
# std          0.00       23.93        5.48        4.75        6.00     NaN
# min         16.00        6.00      -39.16      -39.16      -40.02     NaN
# 25%         16.00       16.00       -4.16       -0.08       -7.46     NaN
# 50%         16.00       18.00       -0.31        3.45       -2.12     NaN
# 75%         16.00       66.00        2.35        7.30        2.12     NaN
# max         16.00       91.00       40.02       39.16       40.02     NaN
#
#        Y_Gyro  Z_Gyro        Code   Frequency        User  Trial
# count    0.00    0.00 24035238.00 24035238.00 24035238.00   0.00
# mean      NaN     NaN      301.00       25.00       27.79    NaN
# std       NaN     NaN        0.00        0.00        5.93    NaN
# ...

# %% [markdown]
# ###Describe del watch 3

# %% [markdown]
# ####Después

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

df3.describe()
# Out:
#           Dataset    Activity       X_Acc       Y_Acc       Z_Acc  X_Gyro  \
# count 58760504.00 58760504.00 58760504.00 58760504.00 58290662.00    0.00
# mean        16.00       31.25       -0.52        1.96       -3.56     NaN
# std          0.00       23.97        4.83        5.01        6.12     NaN
# min         16.00        6.00      -37.98      -40.02      -40.02     NaN
# 25%         16.00       16.00       -3.53       -0.55       -9.42     NaN
# 50%         16.00       18.00       -0.16        1.49       -4.94     NaN
# 75%         16.00       61.00        1.18        5.96        0.63     NaN
# max         16.00       91.00       39.79       40.02       40.02     NaN
#
#        Y_Gyro  Z_Gyro        Code   Frequency        User  Trial
# count    0.00    0.00 58760504.00 58760504.00 58760504.00   0.00
# mean      NaN     NaN      301.00       50.00       45.20    NaN
# std       NaN     NaN        0.00        0.00        5.59    NaN
# ...

# %% [markdown]
# ####Antes

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

data3.describe()
# Out:
#           Dataset    Activity       X_Acc       Y_Acc       Z_Acc  X_Gyro  \
# count 29380252.00 29380252.00 29380252.00 29380252.00 29145102.00    0.00
# mean        16.00       31.25       -0.52        1.96       -3.56     NaN
# std          0.00       23.97        4.83        5.01        6.12     NaN
# min         16.00        6.00      -37.98      -40.02      -40.02     NaN
# 25%         16.00       16.00       -3.53       -0.55       -9.42     NaN
# 50%         16.00       18.00       -0.16        1.49       -4.94     NaN
# 75%         16.00       61.00        1.18        5.96        0.63     NaN
# max         16.00       91.00       39.79       40.02       40.02     NaN
#
#        Y_Gyro  Z_Gyro        Code   Frequency        User  Trial
# count    0.00    0.00 29380252.00 29380252.00 29380252.00   0.00
# mean      NaN     NaN      301.00       25.00       45.20    NaN
# std       NaN     NaN        0.00        0.00        5.59    NaN
# ...

# %% [markdown]
# ##Analisis gráfico del dataset 16 watch

# %% [markdown]
# ###Valores válidos de acelerometro

# %%
df = final.copy()

# %%
#watch 1
grafico_acelerometro_valido(df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#watch 2
grafico_acelerometro_valido(df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#watch 3
grafico_acelerometro_valido(df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###Valores máximo y mínimos acelerometro

# %%
#watch 1
grafico_acelerometro_max_min(df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#watch 2
grafico_acelerometro_max_min(df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#watch 3
grafico_acelerometro_max_min(df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Valores Válidos Giroscopio

# %%
#watch 1
grafico_giroscopio_valido(df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#watch 2
grafico_giroscopio_valido(df)

# %%
#watch 3
grafico_giroscopio_valido(df)

# %% [markdown]
# ###Valores Máximo y Mínimos Giroscopio

# %%
#watch 1
grafico_giroscopio_max_min(df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#watch 2
grafico_giroscopio_max_min(df)

# %%
#watch 3
grafico_giroscopio_max_min(df)

# %% [markdown]
# ###Actividades válidas

# %%
#watch 1
grafico_activity(df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#watch 2
grafico_activity(df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#watch 3
grafico_activity(df)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #**Smartphone**

# %% [markdown]
# ###Eliminación de las filas NaN de activity

# %% [markdown]
# Adicionalmente la eliminación de las filas que tengan como ubicación PHONE_IN_BAG	PHONE_ON_TABLE	PHONE_AWAY_FROM_ME	PHONE_-_SOMEONE_ELSE_USING_IT	PHONE_STRAPPED dado a que pueden comprometer la data

# %%
phone_1 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone/phone_1.dat', delimiter=' ')
# Out:
# <ipython-input-3-660fa21afec2>:1: DtypeWarning: Columns (7,8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   phone_1 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone/phone_1.dat', delimiter=' ')

# %%
phone_1
# Out:
#                            TimeStamp     X_Acc     Y_Acc      Z_Acc    X_Gyro  \
# 0         2015-12-13 21:25:16.931735  0.006866 -0.000641  -0.997757  0.000671
# 1         2015-12-13 21:25:17.008517  0.004181  0.001450  -0.995285  0.000659
# 2         2015-12-13 21:25:17.055758  0.008514 -0.000671  -0.994827  0.000660
# 3         2015-12-13 21:25:17.085299  0.006805  0.000137  -0.996704  0.000659
# 4         2015-12-13 21:25:17.114810  0.004044 -0.000549  -0.998108  0.000657
# ...                              ...       ...       ...        ...       ...
# 29002395  2061-05-06 07:12:34.345311 -0.222661  0.030526  10.302250  0.008522
# 29002396  2061-05-06 07:12:34.367073 -0.212485  0.016161  10.274716  0.008256
# 29002397  2061-05-06 07:12:34.386712 -0.208296  0.025738  10.306439  0.009321
# 29002398  2061-05-06 07:12:34.407181 -0.217274  0.014964  10.262746  0.007457
# 29002399  2061-05-06 07:12:34.426242 -0.195127  0.067636  10.279505  0.007723
#
# ...

# %%
phone_1.dropna(subset=['Activity'], inplace=True)

# %%
phone_1
# Out:
#                            TimeStamp     X_Acc     Y_Acc      Z_Acc    X_Gyro  \
# 3200      2015-12-13 21:33:52.707966  0.014877  0.009903  -0.985733 -0.001344
# 3201      2015-12-13 21:33:52.769001 -0.004425  0.000397  -1.007645  0.000787
# 3202      2015-12-13 21:33:52.798511  0.007492 -0.002777  -1.001984  0.001843
# 3203      2015-12-13 21:33:52.828052  0.011185 -0.000610  -0.997498 -0.000277
# 3204      2015-12-13 21:33:52.857593  0.002335  0.004868  -1.000549 -0.002402
# ...                              ...       ...       ...        ...       ...
# 28313595  2061-05-04 00:31:20.807998 -0.239420  0.203507  10.281301  0.005593
# 28313596  2061-05-04 00:31:20.827422 -0.241216  0.191536  10.275315  0.007989
# 28313597  2061-05-04 00:31:20.845879 -0.254982  0.207098  10.251373  0.006658
# 28313598  2061-05-04 00:31:20.866186 -0.244807  0.190339  10.264542  0.008256
# 28313599  2061-05-04 00:31:20.884750 -0.237026  0.201113  10.266935  0.006924
#
# ...

# %%
#Eliminación de las ubicaciones
values_to_remove = [
    'PHONE_IN_BAG',
    'PHONE_ON_TABLE',
    'PHONE_AWAY_FROM_ME',
    'PHONE_-_SOMEONE_ELSE_USING_IT',
    'PHONE_STRAPPE'
]

phone_1 = phone_1[~phone_1['Location'].isin(values_to_remove)]

phone_1.reset_index(drop=True, inplace=True)

# %%
phone_1
# Out:
#                            TimeStamp     X_Acc     Y_Acc      Z_Acc    X_Gyro  \
# 0         2015-12-13 21:33:52.707966  0.014877  0.009903  -0.985733 -0.001344
# 1         2015-12-13 21:33:52.769001 -0.004425  0.000397  -1.007645  0.000787
# 2         2015-12-13 21:33:52.798511  0.007492 -0.002777  -1.001984  0.001843
# 3         2015-12-13 21:33:52.828052  0.011185 -0.000610  -0.997498 -0.000277
# 4         2015-12-13 21:33:52.857593  0.002335  0.004868  -1.000549 -0.002402
# ...                              ...       ...       ...        ...       ...
# 12786395  2061-05-04 00:31:20.807998 -0.239420  0.203507  10.281301  0.005593
# 12786396  2061-05-04 00:31:20.827422 -0.241216  0.191536  10.275315  0.007989
# 12786397  2061-05-04 00:31:20.845879 -0.254982  0.207098  10.251373  0.006658
# 12786398  2061-05-04 00:31:20.866186 -0.244807  0.190339  10.264542  0.008256
# 12786399  2061-05-04 00:31:20.884750 -0.237026  0.201113  10.266935  0.006924
#
# ...

# %%
phone_1.to_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone_NAN/phone_1.dat',index=False)

# %% [markdown]
# Ahora a la parte 2

# %%
phone_2 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone/phone_2.dat', delimiter=' ')
# Out:
# <ipython-input-12-5fb3f0c3b7f4>:1: DtypeWarning: Columns (7,8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   phone_2 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone/phone_2.dat', delimiter=' ')

# %%
phone_2
# Out:
#                            TimeStamp     X_Acc     Y_Acc     Z_Acc    X_Gyro  \
# 0         2015-09-26 13:33:47.511312  0.010559  0.011841 -1.014877 -0.001384
# 1         2015-09-26 13:33:47.540938  0.006989  0.009689 -1.017532  0.001815
# 2         2015-09-26 13:33:47.570588  0.007385  0.009964 -1.014740 -0.001364
# 3         2015-09-26 13:33:47.600215  0.010056  0.011230 -1.015594 -0.000304
# 4         2015-09-26 13:33:47.629843  0.008698  0.010330 -1.012024  0.001828
# ...                              ...       ...       ...       ...       ...
# 26721595  2015-09-03 23:05:29.583403 -0.261093 -0.263412 -0.993744 -0.301079
# 26721596  2015-09-03 23:05:29.613086 -0.201950 -0.270065 -1.009430 -0.042280
# 26721597  2015-09-03 23:05:29.644741 -0.194321 -0.272903 -1.016281  0.028823
# 26721598  2015-09-03 23:05:29.674419 -0.098877 -0.257828 -0.945999 -0.241186
# 26721599  2015-09-03 23:05:29.704099 -0.050217 -0.268417 -0.903870 -0.338490
#
# ...

# %%
phone_2.dropna(subset=['Activity'], inplace=True)

# %%
phone_2
# Out:
#                            TimeStamp     X_Acc     Y_Acc     Z_Acc    X_Gyro  \
# 0         2015-09-26 13:33:47.511312  0.010559  0.011841 -1.014877 -0.001384
# 1         2015-09-26 13:33:47.540938  0.006989  0.009689 -1.017532  0.001815
# 2         2015-09-26 13:33:47.570588  0.007385  0.009964 -1.014740 -0.001364
# 3         2015-09-26 13:33:47.600215  0.010056  0.011230 -1.015594 -0.000304
# 4         2015-09-26 13:33:47.629843  0.008698  0.010330 -1.012024  0.001828
# ...                              ...       ...       ...       ...       ...
# 26697595  2015-09-03 22:05:29.979718  0.262741 -0.533615 -0.824997  0.017330
# 26697596  2015-09-03 22:05:30.021794  0.291367 -0.522125 -0.851562 -0.054883
# 26697597  2015-09-03 22:05:30.063037  0.279922 -0.524216 -0.767334 -0.138755
# 26697598  2015-09-03 22:05:30.104786  0.237930 -0.514542 -0.826096 -0.163779
# 26697599  2015-09-03 22:05:30.146633  0.306641 -0.525009 -0.837830 -0.177085
#
# ...

# %%
#Eliminación de las ubicaciones
values_to_remove = [
    'PHONE_IN_BAG',
    'PHONE_ON_TABLE',
    'PHONE_AWAY_FROM_ME',
    'PHONE_-_SOMEONE_ELSE_USING_IT',
    'PHONE_STRAPPE'
]

phone_2 = phone_2[~phone_2['Location'].isin(values_to_remove)]

phone_2.reset_index(drop=True, inplace=True)

# %%
phone_2
# Out:
#                            TimeStamp     X_Acc     Y_Acc     Z_Acc    X_Gyro  \
# 0         2015-09-26 13:33:47.511312  0.010559  0.011841 -1.014877 -0.001384
# 1         2015-09-26 13:33:47.540938  0.006989  0.009689 -1.017532  0.001815
# 2         2015-09-26 13:33:47.570588  0.007385  0.009964 -1.014740 -0.001364
# 3         2015-09-26 13:33:47.600215  0.010056  0.011230 -1.015594 -0.000304
# 4         2015-09-26 13:33:47.629843  0.008698  0.010330 -1.012024  0.001828
# ...                              ...       ...       ...       ...       ...
# 12644795  2015-09-03 22:05:29.979718  0.262741 -0.533615 -0.824997  0.017330
# 12644796  2015-09-03 22:05:30.021794  0.291367 -0.522125 -0.851562 -0.054883
# 12644797  2015-09-03 22:05:30.063037  0.279922 -0.524216 -0.767334 -0.138755
# 12644798  2015-09-03 22:05:30.104786  0.237930 -0.514542 -0.826096 -0.163779
# 12644799  2015-09-03 22:05:30.146633  0.306641 -0.525009 -0.837830 -0.177085
#
# ...

# %%
phone_2.to_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone_NAN/phone_2.dat',index=False)

# %% [markdown]
# Ahora para el phone 3

# %%
phone_3 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone/phone_3.dat', delimiter=' ')
# Out:
# <ipython-input-19-313e84b489cd>:1: DtypeWarning: Columns (7,8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   phone_3 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone/phone_3.dat', delimiter=' ')

# %%
phone_3
# Out:
#                            TimeStamp     X_Acc     Y_Acc      Z_Acc    X_Gyro  \
# 0         2015-11-12 07:08:23.017554  0.497994  0.794875  10.486604 -0.643439
# 1         2015-11-12 07:08:23.037322  0.383072  2.030283   9.998186 -0.216255
# 2         2015-11-12 07:08:23.057055  0.344765  1.685518  11.549629 -0.255671
# 3         2015-11-12 07:08:23.076802 -1.848324  1.407791  10.793061 -0.214125
# 4         2015-11-12 07:08:23.096979 -1.235408  0.967257  10.936713 -0.170448
# ...                              ...       ...       ...        ...       ...
# 14733595  2015-08-20 09:13:18.409892  0.005066  0.002319  -0.992172 -0.023137
# 14733596  2015-08-20 09:13:18.433829  0.005981  0.003784  -0.991089 -0.022024
# 14733597  2015-08-20 09:13:18.457786  0.007584  0.003479  -0.990112 -0.008220
# 14733598  2015-08-20 09:13:18.481739  0.006577  0.002151  -0.992264  0.003506
# 14733599  2015-08-20 09:13:18.505681  0.006332  0.001099  -0.993286  0.003528
#
# ...

# %%
phone_3.dropna(subset=['Activity'], inplace=True)

# %%
phone_3
# Out:
#                            TimeStamp     X_Acc     Y_Acc      Z_Acc    X_Gyro  \
# 0         2015-11-12 07:08:23.017554  0.497994  0.794875  10.486604 -0.643439
# 1         2015-11-12 07:08:23.037322  0.383072  2.030283   9.998186 -0.216255
# 2         2015-11-12 07:08:23.057055  0.344765  1.685518  11.549629 -0.255671
# 3         2015-11-12 07:08:23.076802 -1.848324  1.407791  10.793061 -0.214125
# 4         2015-11-12 07:08:23.096979 -1.235408  0.967257  10.936713 -0.170448
# ...                              ...       ...       ...        ...       ...
# 14733595  2015-08-20 09:13:18.409892  0.005066  0.002319  -0.992172 -0.023137
# 14733596  2015-08-20 09:13:18.433829  0.005981  0.003784  -0.991089 -0.022024
# 14733597  2015-08-20 09:13:18.457786  0.007584  0.003479  -0.990112 -0.008220
# 14733598  2015-08-20 09:13:18.481739  0.006577  0.002151  -0.992264  0.003506
# 14733599  2015-08-20 09:13:18.505681  0.006332  0.001099  -0.993286  0.003528
#
# ...

# %%
#Eliminación de las ubicaciones
values_to_remove = [
    'PHONE_IN_BAG',
    'PHONE_ON_TABLE',
    'PHONE_AWAY_FROM_ME',
    'PHONE_-_SOMEONE_ELSE_USING_IT',
    'PHONE_STRAPPE'
]

phone_3 = phone_3[~phone_3['Location'].isin(values_to_remove)]

phone_3.reset_index(drop=True, inplace=True)

# %%
phone_3
# Out:
#                           TimeStamp     X_Acc      Y_Acc     Z_Acc    X_Gyro  \
# 0        2015-11-12 09:03:38.190865  3.658340 -11.051635  1.331176 -0.001065
# 1        2015-11-12 09:03:38.211026  4.290410 -12.133814  2.499547 -0.001065
# 2        2015-11-12 09:03:38.230509  4.884171 -13.905523  4.759673 -0.308936
# 3        2015-11-12 09:03:38.250398  3.754108 -14.020445  4.481946 -0.147011
# 4        2015-11-12 09:03:38.269974  1.685518 -13.713987  1.599327  0.132097
# ...                             ...       ...        ...       ...       ...
# 6182395  2015-08-20 09:13:18.409892  0.005066   0.002319 -0.992172 -0.023137
# 6182396  2015-08-20 09:13:18.433829  0.005981   0.003784 -0.991089 -0.022024
# 6182397  2015-08-20 09:13:18.457786  0.007584   0.003479 -0.990112 -0.008220
# 6182398  2015-08-20 09:13:18.481739  0.006577   0.002151 -0.992264  0.003506
# 6182399  2015-08-20 09:13:18.505681  0.006332   0.001099 -0.993286  0.003528
#
# ...

# %%
phone_3.to_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone_NAN/phone_3.dat',index=False)

# %% [markdown]
# ###Actividades unicas del phone_1

# %%
phone_1 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone_NAN/phone_1.dat', sep=',')
# Out:
# <ipython-input-26-da4a1d9f2f35>:1: DtypeWarning: Columns (8,9,10) have mixed types. Specify dtype option on import or set low_memory=False.
#   phone_1 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone_NAN/phone_1.dat', sep=',')

# %%
phone_1
# Out:
#                            TimeStamp     X_Acc     Y_Acc      Z_Acc    X_Gyro  \
# 0         2015-12-13 21:33:52.707966  0.014877  0.009903  -0.985733 -0.001344
# 1         2015-12-13 21:33:52.769001 -0.004425  0.000397  -1.007645  0.000787
# 2         2015-12-13 21:33:52.798511  0.007492 -0.002777  -1.001984  0.001843
# 3         2015-12-13 21:33:52.828052  0.011185 -0.000610  -0.997498 -0.000277
# 4         2015-12-13 21:33:52.857593  0.002335  0.004868  -1.000549 -0.002402
# ...                              ...       ...       ...        ...       ...
# 12786395  2061-05-04 00:31:20.807998 -0.239420  0.203507  10.281301  0.005593
# 12786396  2061-05-04 00:31:20.827422 -0.241216  0.191536  10.275315  0.007989
# 12786397  2061-05-04 00:31:20.845879 -0.254982  0.207098  10.251373  0.006658
# 12786398  2061-05-04 00:31:20.866186 -0.244807  0.190339  10.264542  0.008256
# 12786399  2061-05-04 00:31:20.884750 -0.237026  0.201113  10.266935  0.006924
#
# ...

# %%
phone_1_copy = phone_1.copy()
phone_1_copy.drop(columns=['Activity_3'], inplace=True)
phone_1_copy['Activity'] = phone_1_copy['Activity'].fillna('') + '-' + phone_1_copy['Activity_2'].fillna('')
phone_1_copy.drop(columns=['Activity_2'], inplace=True)

# %%
unique_activities = phone_1_copy['Activity'].unique()
unique_activities
# Out:
# array(['SITTING-', 'WALKING-TEXTING', 'WALKING-DRINKING__NON-ALCOHOL_',
#        'SITTING-TOILET', 'STANDING_IN_PLACE-', 'WALKING-',
#        'STANDING_AND_MOVING-STAIRS_-_GOING_DOWN',
#        'STANDING_AND_MOVING-STAIRS_-_GOING_UP', 'SITTING-EATING',
#        'STANDING_AND_MOVING-', 'LYING_DOWN-SLEEPING',
#        'STANDING_IN_PLACE-BATHING_-_SHOWER', 'SITTING-DRESSING',
#        'WALKING-EATING', 'STANDING_AND_MOVING-BATHING_-_SHOWER',
#        'STANDING_IN_PLACE-TOILET', 'WALKING-STAIRS_-_GOING_DOWN',
#        'WALKING-STAIRS_-_GOING_UP', 'RUNNING-', 'BICYCLING-',
#        'SITTING-COMPUTER_WORK', 'WALKING-TOILET',
#        'STANDING_AND_MOVING-EATING', 'SITTING-PLAYING_VIDEOGAMES',
#        'LYING_DOWN-', 'STANDING_AND_MOVING-COOKING',
#        'STANDING_AND_MOVING-COMPUTER_WORK',
#        'STANDING_AND_MOVING-ON_A_BUS', 'SITTING-DRIVE_-_I_M_THE_DRIVER',
#        'STANDING_IN_PLACE-ON_A_BUS',
#        'STANDING_AND_MOVING-PLAYING_BASEBALL',
# ...

# %%
phone_1_copy.to_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone_activity/phone_1.dat',index=False)

# %% [markdown]
# ###Actividades unicas del phone_2

# %%
phone_2_copy = phone_2.copy()
phone_2_copy.drop(columns=['Activity_3'], inplace=True)
phone_2_copy['Activity'] = phone_2_copy['Activity'].fillna('') + '-' + phone_2_copy['Activity_2'].fillna('')
phone_2_copy.drop(columns=['Activity_2'], inplace=True)

# %%
unique_activities = phone_2_copy['Activity'].unique()
unique_activities
# Out:
# array(['SITTING-', 'WALKING-', 'BICYCLING-', 'SITTING-EATING',
#        'SITTING-SURFING_THE_INTERNET', 'STANDING_AND_MOVING-',
#        'STANDING_AND_MOVING-SURFING_THE_INTERNET', 'STANDING_IN_PLACE-',
#        'SITTING-SMOKING', 'LYING_DOWN-SLEEPING', 'LYING_DOWN-',
#        'STANDING_AND_MOVING-EATING', 'WALKING-TEXTING',
#        'LYING_DOWN-EATING', 'BICYCLING-SURFING_THE_INTERNET',
#        'STANDING_IN_PLACE-SLEEPING', 'WALKING-EATING',
#        'WALKING-SURFING_THE_INTERNET', 'SITTING-SLEEPING',
#        'WALKING-STAIRS_-_GOING_UP', 'SITTING-DRIVE_-_I_M_THE_DRIVER',
#        'BICYCLING-EXERCISING', 'STANDING_AND_MOVING-BATHING_-_SHOWER',
#        'SITTING-TEXTING', 'SITTING-TOILET', 'SITTING-COMPUTER_WORK',
#        'STANDING_IN_PLACE-TEXTING', 'STANDING_AND_MOVING-COOKING',
#        'STANDING_IN_PLACE-TOILET', 'LYING_DOWN-READING_A_BOOK',
#        'STANDING_AND_MOVING-TOILET', 'SITTING-DRINKING__NON-ALCOHOL_',
# ...

# %%
phone_2_copy.to_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone_activity/phone_2.dat',index=False)

# %% [markdown]
# ###Actividades unicas del phone_3

# %%
phone_3_copy = phone_3.copy()
phone_3_copy.drop(columns=['Activity_3'], inplace=True)
phone_3_copy['Activity'] = phone_3_copy['Activity'].fillna('') + '-' + phone_3_copy['Activity_2'].fillna('')
phone_3_copy.drop(columns=['Activity_2'], inplace=True)

# %%
unique_activities = phone_3_copy['Activity'].unique()
unique_activities
# Out:
# array(['WALKING-', 'SITTING-', 'SITTING-ON_A_BUS',
#        'SITTING-DRIVE_-_I_M_THE_DRIVER', 'BICYCLING-',
#        'STANDING_IN_PLACE-', 'SITTING-TEXTING',
#        'SITTING-SURFING_THE_INTERNET', 'STANDING_AND_MOVING-',
#        'STANDING_IN_PLACE-TEXTING', 'LYING_DOWN-',
#        'WALKING-STAIRS_-_GOING_DOWN', 'STANDING_AND_MOVING-COOKING',
#        'SITTING-TOILET', 'STANDING_AND_MOVING-CLEANING',
#        'LYING_DOWN-TEXTING', 'SITTING-EATING', 'LYING_DOWN-EATING',
#        'STANDING_AND_MOVING-BATHING_-_SHOWER', 'WALKING-TEXTING',
#        'LYING_DOWN-READING_A_BOOK', 'LYING_DOWN-WATCHING_TV',
#        'SITTING-WATCHING_TV', 'RUNNING-',
#        'STANDING_IN_PLACE-COMPUTER_WORK', 'LYING_DOWN-COMPUTER_WORK',
#        'STANDING_IN_PLACE-ON_A_BUS', 'SITTING-READING_A_BOOK',
#        'LYING_DOWN-SLEEPING', 'SITTING-IN_A_CAR',
#        'STANDING_IN_PLACE-STRETCHING', 'SITTING-COMPUTER_WORK'],
#       dtype=object)

# %%
phone_3_copy.to_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone_activity/phone_3.dat',index=False)

# %% [markdown]
# ###Actividades unicas en general

# %%
array_1 = ['SITTING-', 'WALKING-TEXTING', 'WALKING-DRINKING__NON-ALCOHOL_',
       'SITTING-TOILET', 'STANDING_IN_PLACE-', 'WALKING-',
       'STANDING_AND_MOVING-STAIRS_-_GOING_DOWN',
       'STANDING_AND_MOVING-STAIRS_-_GOING_UP', 'SITTING-EATING',
       'STANDING_AND_MOVING-', 'LYING_DOWN-SLEEPING',
       'STANDING_IN_PLACE-BATHING_-_SHOWER', 'SITTING-DRESSING',
       'WALKING-EATING', 'STANDING_AND_MOVING-BATHING_-_SHOWER',
       'STANDING_IN_PLACE-TOILET', 'WALKING-STAIRS_-_GOING_DOWN',
       'WALKING-STAIRS_-_GOING_UP', 'RUNNING-', 'BICYCLING-',
       'SITTING-COMPUTER_WORK', 'WALKING-TOILET',
       'STANDING_AND_MOVING-EATING', 'SITTING-PLAYING_VIDEOGAMES',
       'LYING_DOWN-', 'STANDING_AND_MOVING-COOKING',
       'STANDING_AND_MOVING-COMPUTER_WORK',
       'STANDING_AND_MOVING-ON_A_BUS', 'SITTING-DRIVE_-_I_M_THE_DRIVER',
       'STANDING_IN_PLACE-ON_A_BUS',
       'STANDING_AND_MOVING-PLAYING_BASEBALL',
       'STANDING_IN_PLACE-COOKING', 'SITTING-ON_A_BUS',
       'STANDING_AND_MOVING-TOILET', 'STANDING_AND_MOVING-WASHING_DISHES',
       'STANDING_AND_MOVING-CLEANING', 'SITTING-SURFING_THE_INTERNET',
       'STANDING_IN_PLACE-STRETCHING', 'STANDING_AND_MOVING-DRESSING',
       'RUNNING-EXERCISING', 'WALKING-EXERCISING', 'BICYCLING-EXERCISING',
       'STANDING_AND_MOVING-STRETCHING', 'STANDING_IN_PLACE-DRESSING',
       'STANDING_AND_MOVING-EXERCISING', 'LYING_DOWN-STRETCHING',
       'SITTING-DRINKING__NON-ALCOHOL_', 'SITTING-WATCHING_TV',
       'STANDING_IN_PLACE-DRINKING__NON-ALCOHOL_', 'LYING_DOWN-EATING',
       'SITTING-READING_A_BOOK', 'STANDING_IN_PLACE-COMPUTER_WORK',
       'SITTING-IN_A_CAR', 'STANDING_AND_MOVING-TEXTING',
       'STANDING_AND_MOVING-IN_A_CAR']

############################################################3

array_2 = ['SITTING-', 'WALKING-', 'BICYCLING-', 'SITTING-EATING',
       'SITTING-SURFING_THE_INTERNET', 'STANDING_AND_MOVING-',
       'STANDING_AND_MOVING-SURFING_THE_INTERNET', 'STANDING_IN_PLACE-',
       'SITTING-SMOKING', 'LYING_DOWN-SLEEPING', 'LYING_DOWN-',
       'STANDING_AND_MOVING-EATING', 'WALKING-TEXTING',
       'LYING_DOWN-EATING', 'BICYCLING-SURFING_THE_INTERNET',
       'STANDING_IN_PLACE-SLEEPING', 'WALKING-EATING',
       'WALKING-SURFING_THE_INTERNET', 'SITTING-SLEEPING',
       'WALKING-STAIRS_-_GOING_UP', 'SITTING-DRIVE_-_I_M_THE_DRIVER',
       'BICYCLING-EXERCISING', 'STANDING_AND_MOVING-BATHING_-_SHOWER',
       'SITTING-TEXTING', 'SITTING-TOILET', 'SITTING-COMPUTER_WORK',
       'STANDING_IN_PLACE-TEXTING', 'STANDING_AND_MOVING-COOKING',
       'STANDING_IN_PLACE-TOILET', 'LYING_DOWN-READING_A_BOOK',
       'STANDING_AND_MOVING-TOILET', 'SITTING-DRINKING__NON-ALCOHOL_',
       'STANDING_AND_MOVING-DOING_LAUNDRY', 'SITTING-IN_A_CAR',
       'LYING_DOWN-SURFING_THE_INTERNET', 'STANDING_AND_MOVING-ELEVATOR',
       'SITTING-ON_A_BUS', 'STANDING_AND_MOVING-CLEANING',
       'STANDING_AND_MOVING-WASHING_DISHES', 'RUNNING-',
       'STANDING_AND_MOVING-TEXTING', 'WALKING-ELEVATOR',
       'WALKING-STAIRS_-_GOING_DOWN', 'STANDING_AND_MOVING-DRESSING',
       'SITTING-COOKING', 'STANDING_IN_PLACE-EATING',
       'SITTING-WATCHING_TV',
       'STANDING_AND_MOVING-DRINKING__NON-ALCOHOL_',
       'LYING_DOWN-WATCHING_TV', 'WALKING-CLEANING',
       'STANDING_IN_PLACE-BATHING_-_SHOWER', 'WALKING-COMPUTER_WORK',
       'STANDING_AND_MOVING-COMPUTER_WORK',
       'STANDING_IN_PLACE-COMPUTER_WORK', 'LYING_DOWN-PLAYING_VIDEOGAMES',
       'SITTING-PLAYING_VIDEOGAMES', 'STANDING_IN_PLACE-COOKING',
       'WALKING-DOING_LAUNDRY', 'WALKING-COOKING', 'WALKING-TOILET']

####################################################################3

array_3 = ['WALKING-', 'SITTING-', 'SITTING-ON_A_BUS',
       'SITTING-DRIVE_-_I_M_THE_DRIVER', 'BICYCLING-',
       'STANDING_IN_PLACE-', 'SITTING-TEXTING',
       'SITTING-SURFING_THE_INTERNET', 'STANDING_AND_MOVING-',
       'STANDING_IN_PLACE-TEXTING', 'LYING_DOWN-',
       'WALKING-STAIRS_-_GOING_DOWN', 'STANDING_AND_MOVING-COOKING',
       'SITTING-TOILET', 'STANDING_AND_MOVING-CLEANING',
       'LYING_DOWN-TEXTING', 'SITTING-EATING', 'LYING_DOWN-EATING',
       'STANDING_AND_MOVING-BATHING_-_SHOWER', 'WALKING-TEXTING',
       'LYING_DOWN-READING_A_BOOK', 'LYING_DOWN-WATCHING_TV',
       'SITTING-WATCHING_TV', 'RUNNING-',
       'STANDING_IN_PLACE-COMPUTER_WORK', 'LYING_DOWN-COMPUTER_WORK',
       'STANDING_IN_PLACE-ON_A_BUS', 'SITTING-READING_A_BOOK',
       'LYING_DOWN-SLEEPING', 'SITTING-IN_A_CAR',
       'STANDING_IN_PLACE-STRETCHING', 'SITTING-COMPUTER_WORK']

# %%
combined_array = array_1 + array_2 + array_3

# Convierte el arreglo combinado en un conjunto para eliminar duplicados
unique_activities_set = set(combined_array)

# Convierte el conjunto nuevamente en una lista
final_array = list(unique_activities_set)

# %%
final_array
# Out:
# ['STANDING_IN_PLACE-BATHING_-_SHOWER',
#  'LYING_DOWN-READING_A_BOOK',
#  'BICYCLING-',
#  'STANDING_AND_MOVING-TOILET',
#  'LYING_DOWN-WATCHING_TV',
#  'WALKING-STAIRS_-_GOING_UP',
#  'STANDING_IN_PLACE-COOKING',
#  'WALKING-DRINKING__NON-ALCOHOL_',
#  'SITTING-SURFING_THE_INTERNET',
#  'LYING_DOWN-SURFING_THE_INTERNET',
#  'STANDING_IN_PLACE-',
#  'LYING_DOWN-PLAYING_VIDEOGAMES',
#  'WALKING-',
#  'STANDING_IN_PLACE-SLEEPING',
#  'STANDING_AND_MOVING-COMPUTER_WORK',
#  'SITTING-DRIVE_-_I_M_THE_DRIVER',
#  'STANDING_IN_PLACE-DRINKING__NON-ALCOHOL_',
#  'STANDING_IN_PLACE-TEXTING',
#  'STANDING_IN_PLACE-COMPUTER_WORK',
#  'WALKING-EATING',
#  'WALKING-COMPUTER_WORK',
#  'STANDING_IN_PLACE-DRESSING',
#  'STANDING_AND_MOVING-DRINKING__NON-ALCOHOL_',
#  'STANDING_AND_MOVING-DOING_LAUNDRY',
#  'WALKING-ELEVATOR',
#  'LYING_DOWN-COMPUTER_WORK',
#  'STANDING_AND_MOVING-WASHING_DISHES',
#  'STANDING_AND_MOVING-SURFING_THE_INTERNET',
#  'WALKING-STAIRS_-_GOING_DOWN',
# ...

# %% [markdown]
# ###Acitividades que phone le aporta a watch

# %%
array_phone = ['STANDING_IN_PLACE-BATHING_-_SHOWER',
 'LYING_DOWN-READING_A_BOOK',
 'BICYCLING-',
 'STANDING_AND_MOVING-TOILET',
 'LYING_DOWN-WATCHING_TV',
 'WALKING-STAIRS_-_GOING_UP',
 'STANDING_IN_PLACE-COOKING',
 'WALKING-DRINKING__NON-ALCOHOL_',
 'SITTING-SURFING_THE_INTERNET',
 'LYING_DOWN-SURFING_THE_INTERNET',
 'STANDING_IN_PLACE-',
 'LYING_DOWN-PLAYING_VIDEOGAMES',
 'WALKING-',
 'STANDING_IN_PLACE-SLEEPING',
 'STANDING_AND_MOVING-COMPUTER_WORK',
 'SITTING-DRIVE_-_I_M_THE_DRIVER',
 'STANDING_IN_PLACE-DRINKING__NON-ALCOHOL_',
 'STANDING_IN_PLACE-TEXTING',
 'STANDING_IN_PLACE-COMPUTER_WORK',
 'WALKING-EATING',
 'WALKING-COMPUTER_WORK',
 'STANDING_IN_PLACE-DRESSING',
 'STANDING_AND_MOVING-DRINKING__NON-ALCOHOL_',
 'STANDING_AND_MOVING-DOING_LAUNDRY',
 'WALKING-ELEVATOR',
 'LYING_DOWN-COMPUTER_WORK',
 'STANDING_AND_MOVING-WASHING_DISHES',
 'STANDING_AND_MOVING-SURFING_THE_INTERNET',
 'WALKING-STAIRS_-_GOING_DOWN',
 'STANDING_AND_MOVING-ELEVATOR',
 'STANDING_IN_PLACE-EATING',
 'WALKING-TEXTING',
 'SITTING-PLAYING_VIDEOGAMES',
 'STANDING_AND_MOVING-PLAYING_BASEBALL',
 'SITTING-READING_A_BOOK',
 'WALKING-DOING_LAUNDRY',
 'LYING_DOWN-TEXTING',
 'SITTING-COOKING',
 'STANDING_IN_PLACE-TOILET',
 'SITTING-TEXTING',
 'SITTING-COMPUTER_WORK',
 'STANDING_AND_MOVING-COOKING',
 'STANDING_AND_MOVING-BATHING_-_SHOWER',
 'STANDING_AND_MOVING-ON_A_BUS',
 'STANDING_IN_PLACE-ON_A_BUS',
 'RUNNING-',
 'SITTING-TOILET',
 'STANDING_AND_MOVING-EXERCISING',
 'SITTING-DRINKING__NON-ALCOHOL_',
 'LYING_DOWN-SLEEPING',
 'STANDING_AND_MOVING-DRESSING',
 'RUNNING-EXERCISING',
 'STANDING_AND_MOVING-TEXTING',
 'STANDING_AND_MOVING-STRETCHING',
 'SITTING-WATCHING_TV',
 'SITTING-',
 'LYING_DOWN-STRETCHING',
 'SITTING-DRESSING',
 'WALKING-TOILET',
 'SITTING-SLEEPING',
 'BICYCLING-SURFING_THE_INTERNET',
 'STANDING_AND_MOVING-',
 'WALKING-COOKING',
 'SITTING-ON_A_BUS',
 'STANDING_IN_PLACE-STRETCHING',
 'WALKING-EXERCISING',
 'LYING_DOWN-EATING',
 'WALKING-SURFING_THE_INTERNET',
 'BICYCLING-EXERCISING',
 'SITTING-IN_A_CAR',
 'SITTING-EATING',
 'STANDING_AND_MOVING-CLEANING',
 'STANDING_AND_MOVING-IN_A_CAR',
 'WALKING-CLEANING',
 'STANDING_AND_MOVING-EATING',
 'STANDING_AND_MOVING-STAIRS_-_GOING_DOWN',
 'LYING_DOWN-',
 'STANDING_AND_MOVING-STAIRS_-_GOING_UP',
 'SITTING-SMOKING']

array_watch = ['SITTING-ON_A_TRAIN',
 'WALKING-',
 'WALKING-DRIVE_-_I_M_THE_DRIVER',
 'SITTING-COMPUTER_WORK',
 'STANDING_AND_MOVING-SLEEPING',
 'SITTING-EATING',
 'STANDING_IN_PLACE-SURFING_THE_INTERNET',
 'RUNNING-PLAYING_BASEBALL',
 'STANDING_AND_MOVING-ON_A_BUS',
 'SITTING-PLAYING_VIDEOGAMES',
 'WALKING-SURFING_THE_INTERNET',
 'SITTING-COOKING',
 'STANDING_AND_MOVING-DOING_LAUNDRY',
 'STANDING_AND_MOVING-BATHING_-_SHOWER',
 'STANDING_IN_PLACE-TEXTING',
 'WALKING-COMPUTER_WORK',
 'BICYCLING-SURFING_THE_INTERNET',
 'LYING_DOWN-SURFING_THE_INTERNET',
 'WALKING-DRESSING',
 'STANDING_AND_MOVING-TOILET',
 'LYING_DOWN-TEXTING',
 'STANDING_IN_PLACE-DANCING',
 'SITTING-CLEANING',
 'STANDING_IN_PLACE-DRINKING__NON-ALCOHOL_',
 'STANDING_AND_MOVING-PLAYING_FRISBEE',
 'WALKING-STRETCHING',
 'SITTING-',
 'WALKING-TREADMILL',
 'WALKING-ON_A_TRAIN',
 'STANDING_IN_PLACE-WATCHING_TV',
 'WALKING-COOKING',
 'SITTING-SLEEPING',
 'STANDING_IN_PLACE-WASHING_DISHES',
 'STANDING_AND_MOVING-',
 'STANDING_AND_MOVING-ELEVATOR',
 'LYING_DOWN-STRETCHING',
 'RUNNING-TREADMILL',
 'STANDING_IN_PLACE-ELEVATOR',
 'SITTING-TEXTING',
 'STANDING_AND_MOVING-STAIRS_-_GOING_UP',
 'STANDING_AND_MOVING-WATCHING_TV',
 'WALKING-EATING',
 'LYING_DOWN-PLAYING_PHONE-GAMES',
 'STANDING_IN_PLACE-DRESSING',
 'SITTING-READING_A_BOOK',
 'STANDING_IN_PLACE-DRIVE_-_I_M_THE_DRIVER',
 'STANDING_IN_PLACE-PLAYING_PHONE-GAMES',
 'LYING_DOWN-SLEEPING',
 'LYING_DOWN-PLAYING_VIDEOGAMES',
 'WALKING-STAIRS_-_GOING_DOWN',
 'STANDING_IN_PLACE-CLEANING',
 'SITTING-SURFING_THE_INTERNET',
 'RUNNING-ELLIPTICAL_MACHINE',
 'SITTING-ON_A_BUS',
 'SITTING-YOGA',
 'STANDING_AND_MOVING-DRESSING',
 'WALKING-STAIRS_-_GOING_UP',
 'WALKING-SKATEBOARDING',
 'LYING_DOWN-WATCHING_TV',
 'SITTING-DRESSING',
 'LYING_DOWN-COMPUTER_WORK',
 'SITTING-TOILET',
 'LYING_DOWN-EATING',
 'SITTING-SMOKING',
 'WALKING-WATCHING_TV',
 'WALKING-ELEVATOR',
 'STANDING_AND_MOVING-DRIVE_-_I_M_THE_DRIVER',
 'STANDING_IN_PLACE-DOING_LAUNDRY',
 'SITTING-PLAYING_PHONE-GAMES',
 'IN_A_CAR-',
 'STANDING_AND_MOVING-PLAYING_BASEBALL',
 'SITTING-MOTORBIKE',
 'STANDING_AND_MOVING-EXERCISING',
 'STANDING_AND_MOVING-COOKING',
 'WALKING-TEXTING',
 'BICYCLING-',
 'STANDING_IN_PLACE-COOKING',
 'STANDING_IN_PLACE-STRETCHING',
 'LYING_DOWN-TOILET',
 'SITTING-DRIVE_-_I_M_THE_DRIVER',
 'STANDING_AND_MOVING-STAIRS_-_GOING_DOWN',
 'STANDING_AND_MOVING-CLEANING',
 'LYING_DOWN-READING_A_BOOK',
 'WALKING-ON_A_BUS',
 'STANDING_IN_PLACE-COMPUTER_WORK',
 'STANDING_AND_MOVING-TEXTING',
 'WALKING-DOING_LAUNDRY',
 'STANDING_AND_MOVING-WASHING_DISHES',
 'STANDING_AND_MOVING-EATING',
 'STANDING_IN_PLACE-ON_A_TRAIN',
 'STANDING_IN_PLACE-BATHING_-_SHOWER',
 'STANDING_IN_PLACE-',
 'STANDING_IN_PLACE-TOILET',
 'STANDING_AND_MOVING-STRETCHING',
 'BICYCLING-EXERCISING',
 'BICYCLING-STATIONARY_BIKE',
 'RUNNING-EXERCISING',
 'STANDING_IN_PLACE-YOGA',
 'STANDING_IN_PLACE-ON_A_BUS',
 'STANDING_AND_MOVING-SKATEBOARDING',
 'SITTING-WATCHING_TV',
 'STANDING_AND_MOVING-COMPUTER_WORK',
 'LYING_DOWN-',
 'STANDING_IN_PLACE-EATING',
 'RUNNING-STAIRS_-_GOING_UP',
 'WALKING-IN_A_CAR',
 'SITTING-IN_A_CAR',
 'SITTING-DRINKING__NON-ALCOHOL_',
 'STANDING_AND_MOVING-SURFING_THE_INTERNET',
 'LYING_DOWN-DRINKING__NON-ALCOHOL_',
 'WALKING-TOILET',
 'SITTING-DANCING',
 'WALKING-CLEANING',
 'STANDING_IN_PLACE-SLEEPING',
 'SITTING-WASHING_DISHES',
 'EATING-',
 'WALKING-DRINKING__NON-ALCOHOL_',
 'WALKING-BATHING_-_SHOWER',
 'WALKING-EXERCISING',
 'STANDING_AND_MOVING-DRINKING__NON-ALCOHOL_',
 'RUNNING-',
 'SITTING-STRETCHING',
 'STANDING_IN_PLACE-PLAYING_VIDEOGAMES',
 'BICYCLING-SKATEBOARDING']

# %%
set_phone = set(array_phone)
set_watch = set(array_watch)

# Realizar la diferencia entre los conjuntos
strings_not_in_watch = list(set_phone - set_watch)

# %%
strings_not_in_watch
# Out:
# ['STANDING_AND_MOVING-IN_A_CAR']

# %%
strings_not_in_phone = list(set_watch - set_phone)

# %%
strings_not_in_phone
# Out:
# ['SITTING-MOTORBIKE',
#  'WALKING-IN_A_CAR',
#  'STANDING_IN_PLACE-DRIVE_-_I_M_THE_DRIVER',
#  'RUNNING-TREADMILL',
#  'STANDING_IN_PLACE-PLAYING_VIDEOGAMES',
#  'STANDING_AND_MOVING-PLAYING_FRISBEE',
#  'WALKING-BATHING_-_SHOWER',
#  'SITTING-YOGA',
#  'SITTING-WASHING_DISHES',
#  'IN_A_CAR-',
#  'SITTING-DANCING',
#  'RUNNING-ELLIPTICAL_MACHINE',
#  'STANDING_AND_MOVING-DRIVE_-_I_M_THE_DRIVER',
#  'STANDING_IN_PLACE-DANCING',
#  'STANDING_IN_PLACE-DOING_LAUNDRY',
#  'WALKING-SKATEBOARDING',
#  'WALKING-DRESSING',
#  'WALKING-WATCHING_TV',
#  'STANDING_IN_PLACE-WASHING_DISHES',
#  'STANDING_IN_PLACE-PLAYING_PHONE-GAMES',
#  'STANDING_AND_MOVING-WATCHING_TV',
#  'STANDING_AND_MOVING-SKATEBOARDING',
#  'EATING-',
#  'STANDING_IN_PLACE-ON_A_TRAIN',
#  'WALKING-ON_A_BUS',
#  'LYING_DOWN-PLAYING_PHONE-GAMES',
#  'SITTING-PLAYING_PHONE-GAMES',
#  'STANDING_IN_PLACE-SURFING_THE_INTERNET',
#  'STANDING_IN_PLACE-CLEANING',
#  'BICYCLING-STATIONARY_BIKE',
#  'WALKING-DRIVE_-_I_M_THE_DRIVER',
# ...

# %%
array_totales = ['SITTING-ON_A_TRAIN',
 'WALKING-',
 'WALKING-DRIVE_-_I_M_THE_DRIVER',
 'SITTING-COMPUTER_WORK',
 'STANDING_AND_MOVING-SLEEPING',
 'SITTING-EATING',
 'STANDING_IN_PLACE-SURFING_THE_INTERNET',
 'RUNNING-PLAYING_BASEBALL',
 'STANDING_AND_MOVING-ON_A_BUS',
 'SITTING-PLAYING_VIDEOGAMES',
 'WALKING-SURFING_THE_INTERNET',
 'SITTING-COOKING',
 'STANDING_AND_MOVING-DOING_LAUNDRY',
 'STANDING_AND_MOVING-BATHING_-_SHOWER',
 'STANDING_IN_PLACE-TEXTING',
 'WALKING-COMPUTER_WORK',
 'BICYCLING-SURFING_THE_INTERNET',
 'LYING_DOWN-SURFING_THE_INTERNET',
 'WALKING-DRESSING',
 'STANDING_AND_MOVING-TOILET',
 'LYING_DOWN-TEXTING',
 'STANDING_IN_PLACE-DANCING',
 'SITTING-CLEANING',
 'STANDING_IN_PLACE-DRINKING__NON-ALCOHOL_',
 'STANDING_AND_MOVING-PLAYING_FRISBEE',
 'WALKING-STRETCHING',
 'SITTING-',
 'WALKING-TREADMILL',
 'WALKING-ON_A_TRAIN',
 'STANDING_IN_PLACE-WATCHING_TV',
 'WALKING-COOKING',
 'SITTING-SLEEPING',
 'STANDING_IN_PLACE-WASHING_DISHES',
 'STANDING_AND_MOVING-',
 'STANDING_AND_MOVING-ELEVATOR',
 'LYING_DOWN-STRETCHING',
 'RUNNING-TREADMILL',
 'STANDING_IN_PLACE-ELEVATOR',
 'SITTING-TEXTING',
 'STANDING_AND_MOVING-STAIRS_-_GOING_UP',
 'STANDING_AND_MOVING-WATCHING_TV',
 'WALKING-EATING',
 'LYING_DOWN-PLAYING_PHONE-GAMES',
 'STANDING_IN_PLACE-DRESSING',
 'SITTING-READING_A_BOOK',
 'STANDING_IN_PLACE-DRIVE_-_I_M_THE_DRIVER',
 'STANDING_IN_PLACE-PLAYING_PHONE-GAMES',
 'LYING_DOWN-SLEEPING',
 'LYING_DOWN-PLAYING_VIDEOGAMES',
 'WALKING-STAIRS_-_GOING_DOWN',
 'STANDING_IN_PLACE-CLEANING',
 'SITTING-SURFING_THE_INTERNET',
 'RUNNING-ELLIPTICAL_MACHINE',
 'SITTING-ON_A_BUS',
 'SITTING-YOGA',
 'STANDING_AND_MOVING-DRESSING',
 'WALKING-STAIRS_-_GOING_UP',
 'WALKING-SKATEBOARDING',
 'LYING_DOWN-WATCHING_TV',
 'SITTING-DRESSING',
 'LYING_DOWN-COMPUTER_WORK',
 'SITTING-TOILET',
 'LYING_DOWN-EATING',
 'SITTING-SMOKING',
 'WALKING-WATCHING_TV',
 'WALKING-ELEVATOR',
 'STANDING_AND_MOVING-DRIVE_-_I_M_THE_DRIVER',
 'STANDING_IN_PLACE-DOING_LAUNDRY',
 'SITTING-PLAYING_PHONE-GAMES',
 'IN_A_CAR-',
 'STANDING_AND_MOVING-PLAYING_BASEBALL',
 'SITTING-MOTORBIKE',
 'STANDING_AND_MOVING-EXERCISING',
 'STANDING_AND_MOVING-COOKING',
 'WALKING-TEXTING',
 'BICYCLING-',
 'STANDING_IN_PLACE-COOKING',
 'STANDING_IN_PLACE-STRETCHING',
 'LYING_DOWN-TOILET',
 'SITTING-DRIVE_-_I_M_THE_DRIVER',
 'STANDING_AND_MOVING-STAIRS_-_GOING_DOWN',
 'STANDING_AND_MOVING-CLEANING',
 'LYING_DOWN-READING_A_BOOK',
 'WALKING-ON_A_BUS',
 'STANDING_IN_PLACE-COMPUTER_WORK',
 'STANDING_AND_MOVING-TEXTING',
 'WALKING-DOING_LAUNDRY',
 'STANDING_AND_MOVING-WASHING_DISHES',
 'STANDING_AND_MOVING-EATING',
 'STANDING_IN_PLACE-ON_A_TRAIN',
 'STANDING_IN_PLACE-BATHING_-_SHOWER',
 'STANDING_IN_PLACE-',
 'STANDING_IN_PLACE-TOILET',
 'STANDING_AND_MOVING-STRETCHING',
 'BICYCLING-EXERCISING',
 'BICYCLING-STATIONARY_BIKE',
 'RUNNING-EXERCISING',
 'STANDING_IN_PLACE-YOGA',
 'STANDING_IN_PLACE-ON_A_BUS',
 'STANDING_AND_MOVING-SKATEBOARDING',
 'SITTING-WATCHING_TV',
 'STANDING_AND_MOVING-COMPUTER_WORK',
 'LYING_DOWN-',
 'STANDING_IN_PLACE-EATING',
 'RUNNING-STAIRS_-_GOING_UP',
 'WALKING-IN_A_CAR',
 'SITTING-IN_A_CAR',
 'SITTING-DRINKING__NON-ALCOHOL_',
 'STANDING_AND_MOVING-SURFING_THE_INTERNET',
 'LYING_DOWN-DRINKING__NON-ALCOHOL_',
 'WALKING-TOILET',
 'SITTING-DANCING',
 'WALKING-CLEANING',
 'STANDING_IN_PLACE-SLEEPING',
 'SITTING-WASHING_DISHES',
 'EATING-',
 'WALKING-DRINKING__NON-ALCOHOL_',
 'WALKING-BATHING_-_SHOWER',
 'WALKING-EXERCISING',
 'STANDING_AND_MOVING-DRINKING__NON-ALCOHOL_',
 'RUNNING-',
 'SITTING-STRETCHING',
 'STANDING_IN_PLACE-PLAYING_VIDEOGAMES',
 'BICYCLING-SKATEBOARDING'
 'STANDING_AND_MOVING-IN_A_CAR']

array_phone= ['SITTING-MOTORBIKE',
 'WALKING-IN_A_CAR',
 'STANDING_IN_PLACE-DRIVE_-_I_M_THE_DRIVER',
 'RUNNING-TREADMILL',
 'STANDING_IN_PLACE-PLAYING_VIDEOGAMES',
 'STANDING_AND_MOVING-PLAYING_FRISBEE',
 'WALKING-BATHING_-_SHOWER',
 'SITTING-YOGA',
 'SITTING-WASHING_DISHES',
 'IN_A_CAR-',
 'SITTING-DANCING',
 'RUNNING-ELLIPTICAL_MACHINE',
 'STANDING_AND_MOVING-DRIVE_-_I_M_THE_DRIVER',
 'STANDING_IN_PLACE-DANCING',
 'STANDING_IN_PLACE-DOING_LAUNDRY',
 'WALKING-SKATEBOARDING',
 'WALKING-DRESSING',
 'WALKING-WATCHING_TV',
 'STANDING_IN_PLACE-WASHING_DISHES',
 'STANDING_IN_PLACE-PLAYING_PHONE-GAMES',
 'STANDING_AND_MOVING-WATCHING_TV',
 'STANDING_AND_MOVING-SKATEBOARDING',
 'EATING-',
 'STANDING_IN_PLACE-ON_A_TRAIN',
 'WALKING-ON_A_BUS',
 'LYING_DOWN-PLAYING_PHONE-GAMES',
 'SITTING-PLAYING_PHONE-GAMES',
 'STANDING_IN_PLACE-SURFING_THE_INTERNET',
 'STANDING_IN_PLACE-CLEANING',
 'BICYCLING-STATIONARY_BIKE',
 'WALKING-DRIVE_-_I_M_THE_DRIVER',
 'SITTING-ON_A_TRAIN',
 'STANDING_IN_PLACE-YOGA',
 'WALKING-ON_A_TRAIN',
 'LYING_DOWN-DRINKING__NON-ALCOHOL_',
 'STANDING_AND_MOVING-SLEEPING',
 'LYING_DOWN-TOILET',
 'SITTING-STRETCHING',
 'STANDING_IN_PLACE-WATCHING_TV',
 'RUNNING-PLAYING_BASEBALL',
 'SITTING-CLEANING',
 'STANDING_IN_PLACE-ELEVATOR',
 'BICYCLING-SKATEBOARDING',
 'RUNNING-STAIRS_-_GOING_UP',
 'WALKING-STRETCHING',
 'WALKING-TREADMILL']

# %%
set_array_phone = set(array_phone)

# Marcar los elementos en array_totales con una "F" si están en array_phone
for i in range(len(array_totales)):
    if array_totales[i] in set_array_phone:
        array_totales[i] += " (F)"

for item in array_totales:
    print(item)
# Out:
# SITTING-ON_A_TRAIN (F)
# WALKING-
# WALKING-DRIVE_-_I_M_THE_DRIVER (F)
# SITTING-COMPUTER_WORK
# STANDING_AND_MOVING-SLEEPING (F)
# SITTING-EATING
# STANDING_IN_PLACE-SURFING_THE_INTERNET (F)
# RUNNING-PLAYING_BASEBALL (F)
# STANDING_AND_MOVING-ON_A_BUS
# SITTING-PLAYING_VIDEOGAMES
# WALKING-SURFING_THE_INTERNET
# SITTING-COOKING
# STANDING_AND_MOVING-DOING_LAUNDRY
# STANDING_AND_MOVING-BATHING_-_SHOWER
# STANDING_IN_PLACE-TEXTING
# WALKING-COMPUTER_WORK
# BICYCLING-SURFING_THE_INTERNET
# LYING_DOWN-SURFING_THE_INTERNET
# WALKING-DRESSING (F)
# STANDING_AND_MOVING-TOILET
# LYING_DOWN-TEXTING
# STANDING_IN_PLACE-DANCING (F)
# SITTING-CLEANING (F)
# STANDING_IN_PLACE-DRINKING__NON-ALCOHOL_
# STANDING_AND_MOVING-PLAYING_FRISBEE (F)
# WALKING-STRETCHING (F)
# SITTING-
# WALKING-TREADMILL (F)
# WALKING-ON_A_TRAIN (F)
# STANDING_IN_PLACE-WATCHING_TV (F)
# WALKING-COOKING
# SITTING-SLEEPING
# STANDING_IN_PLACE-WASHING_DISHES (F)
# STANDING_AND_MOVING-
# STANDING_AND_MOVING-ELEVATOR
# ...

# %% [markdown]
# ###Preparando el phone_1

# %%
phone_1 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone_activity/phone_1.dat', sep = ',')
# Out:
# <ipython-input-8-d6489e21c011>:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   phone_1 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone_activity/phone_1.dat', sep = ',')

# %%
phone_1
# Out:
#                            TimeStamp     X_Acc     Y_Acc      Z_Acc    X_Gyro  \
# 0         2015-12-13 21:33:52.707966  0.014877  0.009903  -0.985733 -0.001344
# 1         2015-12-13 21:33:52.769001 -0.004425  0.000397  -1.007645  0.000787
# 2         2015-12-13 21:33:52.798511  0.007492 -0.002777  -1.001984  0.001843
# 3         2015-12-13 21:33:52.828052  0.011185 -0.000610  -0.997498 -0.000277
# 4         2015-12-13 21:33:52.857593  0.002335  0.004868  -1.000549 -0.002402
# ...                              ...       ...       ...        ...       ...
# 12786395  2061-05-04 00:31:20.807998 -0.239420  0.203507  10.281301  0.005593
# 12786396  2061-05-04 00:31:20.827422 -0.241216  0.191536  10.275315  0.007989
# 12786397  2061-05-04 00:31:20.845879 -0.254982  0.207098  10.251373  0.006658
# 12786398  2061-05-04 00:31:20.866186 -0.244807  0.190339  10.264542  0.008256
# 12786399  2061-05-04 00:31:20.884750 -0.237026  0.201113  10.266935  0.006924
#
# ...

# %%
num_nan_values = phone_1["Location"].isna().sum()
num_nan_values
# Out:
# 9985600

# %% [markdown]
# Como cuenta con valores NaN podemos reducir bastante el código

# %%
phone_1_1 = phone_1.copy()
conditions = [
    phone_1_1['Location'] == 'PHONE_IN_POCKET',
    phone_1_1['Location'] == 'PHONE_IN_HAND'
]

values = [302, 301]

# A las filas de las cuales desconocemos la ubicación asignamos el código 300, donde el 0 nos informa que no tenemos esa info
phone_1_1['Code'] = np.select(conditions, values, default=300)

# %%
contarfilas = (phone_1_1['Location'] == 'PHONE_IN_POCKET').sum()
contarfilas
# Out:
# 1885600

# %%
phone_1_1
# Out:
#                            TimeStamp     X_Acc     Y_Acc      Z_Acc    X_Gyro  \
# 0         2015-12-13 21:33:52.707966  0.014877  0.009903  -0.985733 -0.001344
# 1         2015-12-13 21:33:52.769001 -0.004425  0.000397  -1.007645  0.000787
# 2         2015-12-13 21:33:52.798511  0.007492 -0.002777  -1.001984  0.001843
# 3         2015-12-13 21:33:52.828052  0.011185 -0.000610  -0.997498 -0.000277
# 4         2015-12-13 21:33:52.857593  0.002335  0.004868  -1.000549 -0.002402
# ...                              ...       ...       ...        ...       ...
# 12786395  2061-05-04 00:31:20.807998 -0.239420  0.203507  10.281301  0.005593
# 12786396  2061-05-04 00:31:20.827422 -0.241216  0.191536  10.275315  0.007989
# 12786397  2061-05-04 00:31:20.845879 -0.254982  0.207098  10.251373  0.006658
# 12786398  2061-05-04 00:31:20.866186 -0.244807  0.190339  10.264542  0.008256
# 12786399  2061-05-04 00:31:20.884750 -0.237026  0.201113  10.266935  0.006924
#
# ...

# %%
phone_1_1 = phone_1_1.drop(columns=['Location'])
phone_1_1.insert(0, 'Dataset', 16)
phone_1_1.insert(1, 'Frequency', 40)
phone_1_1.insert(2, 'Trial', np.nan)
phone_1_1 = phone_1_1.reindex(columns=['Dataset','Activity','X_Acc','Y_Acc','Z_Acc','X_Gyro','Y_Gyro','Z_Gyro','Code','TimeStamp','Frequency','User','Trial'])

# %% [markdown]
# En un principio se planteó que las unidades estaban en mrad/s. Sin embargo esto se corrigió en el cuaderno "Unión de los datasets"

# %%
phone_1_1['X_Acc'] = phone_1_1['X_Acc'] * 9.81
phone_1_1['Y_Acc'] = phone_1_1['Y_Acc'] * 9.81
phone_1_1['Z_Acc'] = phone_1_1['Z_Acc'] * 9.81

phone_1_1['X_Gyro'] = phone_1_1['X_Gyro'] * (180/np.pi) * 1000
phone_1_1['Y_Gyro'] = phone_1_1['Y_Gyro'] * (180/np.pi) * 1000
phone_1_1['Z_Gyro'] = phone_1_1['Z_Gyro'] * (180/np.pi) * 1000

# %%
phone_1_1 = phone_1_1.reset_index(drop=True)

# %%
phone_1_1
# Out:
#           Dataset             Activity     X_Acc     Y_Acc       Z_Acc  \
# 0              16             SITTING-  0.145947  0.097148   -9.670041
# 1              16             SITTING- -0.043410  0.003892   -9.884994
# 2              16             SITTING-  0.073497 -0.027243   -9.829460
# 3              16             SITTING-  0.109722 -0.005988   -9.785451
# 4              16             SITTING-  0.022902  0.047751   -9.815389
# ...           ...                  ...       ...       ...         ...
# 12786395       16  LYING_DOWN-SLEEPING -2.348712  1.996405  100.859558
# 12786396       16  LYING_DOWN-SLEEPING -2.366327  1.878969  100.800843
# 12786397       16  LYING_DOWN-SLEEPING -2.501378  2.031636  100.565972
# 12786398       16  LYING_DOWN-SLEEPING -2.401558  1.867226  100.695153
# 12786399       16  LYING_DOWN-SLEEPING -2.325225  1.972918  100.718636
#
#               X_Gyro      Y_Gyro       Z_Gyro  Code  \
# 0         -76.996402  -79.794005   436.330067   300
# ...

# %%
phone_1_1.to_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone_FINAL/phone_1.dat',index=False)

# %% [markdown]
# ###Preparando el phone_2

# %%
phone_2 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone_activity/phone_2.dat', sep = ',')
# Out:
# <ipython-input-11-4862f0786388>:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   phone_2 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone_activity/phone_2.dat', sep = ',')

# %%
phone_2
# Out:
#                            TimeStamp     X_Acc     Y_Acc     Z_Acc    X_Gyro  \
# 0         2015-09-26 13:33:47.511312  0.010559  0.011841 -1.014877 -0.001384
# 1         2015-09-26 13:33:47.540938  0.006989  0.009689 -1.017532  0.001815
# 2         2015-09-26 13:33:47.570588  0.007385  0.009964 -1.014740 -0.001364
# 3         2015-09-26 13:33:47.600215  0.010056  0.011230 -1.015594 -0.000304
# 4         2015-09-26 13:33:47.629843  0.008698  0.010330 -1.012024  0.001828
# ...                              ...       ...       ...       ...       ...
# 12644795  2015-09-03 22:05:29.979718  0.262741 -0.533615 -0.824997  0.017330
# 12644796  2015-09-03 22:05:30.021794  0.291367 -0.522125 -0.851562 -0.054883
# 12644797  2015-09-03 22:05:30.063037  0.279922 -0.524216 -0.767334 -0.138755
# 12644798  2015-09-03 22:05:30.104786  0.237930 -0.514542 -0.826096 -0.163779
# 12644799  2015-09-03 22:05:30.146633  0.306641 -0.525009 -0.837830 -0.177085
#
# ...

# %%
valoresnan = phone_2['Z_Gyro'].isna().sum()
valoresnan
# Out:
# 14046

# %%
phone_2 = phone_2.dropna(subset=['X_Gyro'])

# %%
phone_2
# Out:
#                            TimeStamp     X_Acc     Y_Acc     Z_Acc    X_Gyro  \
# 0         2015-09-26 13:33:47.511312  0.010559  0.011841 -1.014877 -0.001384
# 1         2015-09-26 13:33:47.540938  0.006989  0.009689 -1.017532  0.001815
# 2         2015-09-26 13:33:47.570588  0.007385  0.009964 -1.014740 -0.001364
# 3         2015-09-26 13:33:47.600215  0.010056  0.011230 -1.015594 -0.000304
# 4         2015-09-26 13:33:47.629843  0.008698  0.010330 -1.012024  0.001828
# ...                              ...       ...       ...       ...       ...
# 12644795  2015-09-03 22:05:29.979718  0.262741 -0.533615 -0.824997  0.017330
# 12644796  2015-09-03 22:05:30.021794  0.291367 -0.522125 -0.851562 -0.054883
# 12644797  2015-09-03 22:05:30.063037  0.279922 -0.524216 -0.767334 -0.138755
# 12644798  2015-09-03 22:05:30.104786  0.237930 -0.514542 -0.826096 -0.163779
# 12644799  2015-09-03 22:05:30.146633  0.306641 -0.525009 -0.837830 -0.177085
#
# ...

# %%
conditions = [
    phone_2['Location'] == 'PHONE_IN_POCKET',
    phone_2['Location'] == 'PHONE_IN_HAND'
]

values = [302, 301]

phone_2['Code'] = np.select(conditions, values, default=300)
# Out:
# <ipython-input-64-74f36ebd903b>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   phone_2['Code'] = np.select(conditions, values, default=300)

# %%
phone_2 = phone_2.drop(columns=['Location'])
phone_2.insert(0, 'Dataset', 16)
phone_2.insert(1, 'Frequency', 40)
phone_2.insert(2, 'Trial', np.nan)
phone_2 = phone_2.reindex(columns=['Dataset','Activity','X_Acc','Y_Acc','Z_Acc','X_Gyro','Y_Gyro','Z_Gyro','Code','TimeStamp','Frequency','User','Trial'])

# %%
phone_2['X_Acc'] = phone_2['X_Acc'] * 9.81
phone_2['Y_Acc'] = phone_2['Y_Acc'] * 9.81
phone_2['Z_Acc'] = phone_2['Z_Acc'] * 9.81

# Convertir valores de giroscopio de mrad/s a dps
phone_2['X_Gyro'] = phone_2['X_Gyro'] * (180/np.pi) * 1000
phone_2['Y_Gyro'] = phone_2['Y_Gyro'] * (180/np.pi) * 1000
phone_2['Z_Gyro'] = phone_2['Z_Gyro'] * (180/np.pi) * 1000

# %%
phone_2 = phone_2.reset_index(drop=True)

# %%
phone_2
# Out:
#           Dataset        Activity     X_Acc     Y_Acc     Z_Acc        X_Gyro  \
# 0              16        SITTING-  0.103585  0.116158 -9.955947    -79.322188
# 1              16        SITTING-  0.068557  0.095052 -9.981992    103.973742
# 2              16        SITTING-  0.072449  0.097747 -9.954599    -78.168447
# 3              16        SITTING-  0.098645  0.110171 -9.962982    -17.401751
# 4              16        SITTING-  0.085323  0.101339 -9.927955    104.708621
# ...           ...             ...       ...       ...       ...           ...
# 12630749       16  SITTING-TOILET  2.577490 -5.234764 -8.093220    992.922849
# 12630750       16  SITTING-TOILET  2.858306 -5.122049 -8.353828  -3144.589425
# 12630751       16  SITTING-TOILET  2.746040 -5.142556 -7.527546  -7950.090892
# 12630752       16  SITTING-TOILET  2.334096 -5.047653 -8.103998  -9383.832122
# 12630753       16  SITTING-TOILET  3.008145 -5.150340 -8.219108 -10146.224668
#
# ...

# %%
phone_2 = phone_2.reset_index(drop=True)
phone_2.to_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone_FINAL/phone_2.dat',index=False)

# %% [markdown]
# ###Preparando el phone_3

# %%
phone_3 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone_activity/phone_3.dat', sep = ',')
# Out:
# <ipython-input-50-48bea6827c8b>:1: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   phone_3 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone_activity/phone_3.dat', sep = ',')

# %%
phone_3
# Out:
#                           TimeStamp     X_Acc      Y_Acc     Z_Acc    X_Gyro  \
# 0        2015-11-12 09:03:38.190865  3.658340 -11.051635  1.331176 -0.001065
# 1        2015-11-12 09:03:38.211026  4.290410 -12.133814  2.499547 -0.001065
# 2        2015-11-12 09:03:38.230509  4.884171 -13.905523  4.759673 -0.308936
# 3        2015-11-12 09:03:38.250398  3.754108 -14.020445  4.481946 -0.147011
# 4        2015-11-12 09:03:38.269974  1.685518 -13.713987  1.599327  0.132097
# ...                             ...       ...        ...       ...       ...
# 6182395  2015-08-20 09:13:18.409892  0.005066   0.002319 -0.992172 -0.023137
# 6182396  2015-08-20 09:13:18.433829  0.005981   0.003784 -0.991089 -0.022024
# 6182397  2015-08-20 09:13:18.457786  0.007584   0.003479 -0.990112 -0.008220
# 6182398  2015-08-20 09:13:18.481739  0.006577   0.002151 -0.992264  0.003506
# 6182399  2015-08-20 09:13:18.505681  0.006332   0.001099 -0.993286  0.003528
#
# ...

# %%
valoresnan = phone_3['Z_Acc'].isna().sum()
valoresnan
# Out:
# 0

# %%
phone_3 = phone_3.dropna(subset=['X_Gyro'])

# %%
conditions = [
    phone_3['Location'] == 'PHONE_IN_POCKET',
    phone_3['Location'] == 'PHONE_IN_HAND'
]

values = [302, 301]

phone_3['Code'] = np.select(conditions, values, default=300)

# %%
phone_3
# Out:
#                           TimeStamp     X_Acc      Y_Acc     Z_Acc    X_Gyro  \
# 0        2015-11-12 09:03:38.190865  3.658340 -11.051635  1.331176 -0.001065
# 1        2015-11-12 09:03:38.211026  4.290410 -12.133814  2.499547 -0.001065
# 2        2015-11-12 09:03:38.230509  4.884171 -13.905523  4.759673 -0.308936
# 3        2015-11-12 09:03:38.250398  3.754108 -14.020445  4.481946 -0.147011
# 4        2015-11-12 09:03:38.269974  1.685518 -13.713987  1.599327  0.132097
# ...                             ...       ...        ...       ...       ...
# 6182395  2015-08-20 09:13:18.409892  0.005066   0.002319 -0.992172 -0.023137
# 6182396  2015-08-20 09:13:18.433829  0.005981   0.003784 -0.991089 -0.022024
# 6182397  2015-08-20 09:13:18.457786  0.007584   0.003479 -0.990112 -0.008220
# 6182398  2015-08-20 09:13:18.481739  0.006577   0.002151 -0.992264  0.003506
# 6182399  2015-08-20 09:13:18.505681  0.006332   0.001099 -0.993286  0.003528
#
# ...

# %%
phone_3 = phone_3.drop(columns=['Location'])
phone_3.insert(0, 'Dataset', 16)
phone_3.insert(1, 'Frequency', 40)
phone_3.insert(2, 'Trial', np.nan)
phone_3 = phone_3.reindex(columns=['Dataset','Activity','X_Acc','Y_Acc','Z_Acc','X_Gyro','Y_Gyro','Z_Gyro','Code','TimeStamp','Frequency','User','Trial'])

# %%
phone_3
# Out:
#          Dataset  Activity     X_Acc      Y_Acc     Z_Acc    X_Gyro    Y_Gyro  \
# 0             16  WALKING-  3.658340 -11.051635  1.331176 -0.001065  0.012784
# 1             16  WALKING-  4.290410 -12.133814  2.499547 -0.001065  0.012784
# 2             16  WALKING-  4.884171 -13.905523  4.759673 -0.308936  1.462653
# 3             16  WALKING-  3.754108 -14.020445  4.481946 -0.147011  2.068807
# 4             16  WALKING-  1.685518 -13.713987  1.599327  0.132097  2.552451
# ...          ...       ...       ...        ...       ...       ...       ...
# 6182395       16  SITTING-  0.005066   0.002319 -0.992172 -0.023137  0.001523
# 6182396       16  SITTING-  0.005981   0.003784 -0.991089 -0.022024 -0.009116
# 6182397       16  SITTING-  0.007584   0.003479 -0.990112 -0.008220  0.000567
# 6182398       16  SITTING-  0.006577   0.002151 -0.992264  0.003506  0.003788
# 6182399       16  SITTING-  0.006332   0.001099 -0.993286  0.003528  0.001634
#
# ...

# %%
phone_3['X_Acc'] = phone_3['X_Acc'] * 9.81
phone_3['Y_Acc'] = phone_3['Y_Acc'] * 9.81
phone_3['Z_Acc'] = phone_3['Z_Acc'] * 9.81

# Convertir valores de giroscopio de mrad/s a dps
phone_3['X_Gyro'] = phone_3['X_Gyro'] * (180/np.pi) * 1000
phone_3['Y_Gyro'] = phone_3['Y_Gyro'] * (180/np.pi) * 1000
phone_3['Z_Gyro'] = phone_3['Z_Gyro'] * (180/np.pi) * 1000

# %%
phone_3
# Out:
#          Dataset  Activity      X_Acc       Y_Acc      Z_Acc        X_Gyro  \
# 0             16  WALKING-  35.888318 -108.416537  13.058838    -61.037018
# 1             16  WALKING-  42.088918 -119.032714  24.520551    -61.037018
# 2             16  WALKING-  47.913722 -136.413184  46.692393 -17700.735762
# 3             16  WALKING-  36.827801 -137.540564  43.967885  -8423.108813
# 4             16  WALKING-  16.534932 -134.534216  15.689395   7568.590676
# ...          ...       ...        ...         ...        ...           ...
# 6182395       16  SITTING-   0.049697    0.022753  -9.733210  -1325.670029
# 6182396       16  SITTING-   0.058678    0.037123  -9.722582  -1261.888335
# 6182397       16  SITTING-   0.074395    0.034129  -9.713002   -470.950401
# 6182398       16  SITTING-   0.064516    0.021106  -9.734108    200.882507
# 6182399       16  SITTING-   0.062121    0.010778  -9.744137    202.116410
#
# ...

# %%
phone_3 = phone_3.reset_index(drop=True)

# %%
phone_3.to_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone_FINAL/phone_3.dat',index=False)

# %% [markdown]
# ##Actividades

# %% [markdown]
# ###Actividades phone 2

# %%
phone2 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone_FINAL/phone_2.dat')

# %%
phone2
# Out:
#           Dataset        Activity     X_Acc     Y_Acc     Z_Acc        X_Gyro  \
# 0              16        SITTING-  0.103585  0.116158 -9.955947    -79.322188
# 1              16        SITTING-  0.068557  0.095052 -9.981992    103.973742
# 2              16        SITTING-  0.072449  0.097747 -9.954599    -78.168447
# 3              16        SITTING-  0.098645  0.110171 -9.962982    -17.401751
# 4              16        SITTING-  0.085323  0.101339 -9.927955    104.708621
# ...           ...             ...       ...       ...       ...           ...
# 12630749       16  SITTING-TOILET  2.577490 -5.234764 -8.093220    992.922849
# 12630750       16  SITTING-TOILET  2.858306 -5.122049 -8.353828  -3144.589425
# 12630751       16  SITTING-TOILET  2.746040 -5.142556 -7.527546  -7950.090892
# 12630752       16  SITTING-TOILET  2.334096 -5.047653 -8.103998  -9383.832122
# 12630753       16  SITTING-TOILET  3.008145 -5.150340 -8.219108 -10146.224668
#
# ...

# %%
mapping = {
    'SITTING-ON_A_TRAIN':65,
 'WALKING-':6,
 'WALKING-DRIVE_-_I_M_THE_DRIVER':100,
 'SITTING-COMPUTER_WORK':16,
 'STANDING_AND_MOVING-SLEEPING':100,
 'SITTING-EATING':16,
 'STANDING_IN_PLACE-SURFING_THE_INTERNET':62,
 'RUNNING-PLAYING_BASEBALL':63,
 'STANDING_AND_MOVING-ON_A_BUS':64,
 'SITTING-PLAYING_VIDEOGAMES':16,
 'WALKING-SURFING_THE_INTERNET':71,
 'SITTING-COOKING':16,
 'STANDING_AND_MOVING-DOING_LAUNDRY':68,
 'STANDING_AND_MOVING-BATHING_-_SHOWER':70,
 'STANDING_IN_PLACE-TEXTING':62,
 'WALKING-COMPUTER_WORK':100,
 'BICYCLING-SURFING_THE_INTERNET':100,
 'LYING_DOWN-SURFING_THE_INTERNET':72,
 'WALKING-DRESSING':73,
 'STANDING_AND_MOVING-TOILET':100,
 'LYING_DOWN-TEXTING':72,
 'STANDING_IN_PLACE-DANCING':74,
 'SITTING-CLEANING':75,
 'STANDING_IN_PLACE-DRINKING__NON-ALCOHOL_':17,
 'STANDING_AND_MOVING-PLAYING_FRISBEE':76,
 'WALKING-STRETCHING':77,
 'SITTING-':16,
 'WALKING-TREADMILL':51,
 'WALKING-ON_A_TRAIN':65,
 'STANDING_IN_PLACE-WATCHING_TV':17,
 'WALKING-COOKING':6,
 'SITTING-SLEEPING':16,
 'STANDING_IN_PLACE-WASHING_DISHES':17,
 'STANDING_AND_MOVING-':68,
 'STANDING_AND_MOVING-ELEVATOR':50,
 'LYING_DOWN-STRETCHING':18,
 'RUNNING-TREADMILL':32,
 'STANDING_IN_PLACE-ELEVATOR':49,
 'SITTING-TEXTING':84,
 'STANDING_AND_MOVING-STAIRS_-_GOING_UP':13,
 'STANDING_AND_MOVING-WATCHING_TV':68,
 'WALKING-EATING':6,
 'LYING_DOWN-PLAYING_PHONE-GAMES':72,
 'STANDING_IN_PLACE-DRESSING':17,
 'SITTING-READING_A_BOOK':16,
 'STANDING_IN_PLACE-DRIVE_-_I_M_THE_DRIVER':100,
 'STANDING_IN_PLACE-PLAYING_PHONE-GAMES':62,
 'LYING_DOWN-SLEEPING':18,
 'LYING_DOWN-PLAYING_VIDEOGAMES':18,
 'WALKING-STAIRS_-_GOING_DOWN':14,
 'STANDING_IN_PLACE-CLEANING':75,
 'SITTING-SURFING_THE_INTERNET':16,
 'RUNNING-ELLIPTICAL_MACHINE':55,
 'SITTING-ON_A_BUS':64,
 'SITTING-YOGA':78,
 'STANDING_AND_MOVING-DRESSING':17,
 'WALKING-STAIRS_-_GOING_UP':13,
 'WALKING-SKATEBOARDING':79,
 'LYING_DOWN-WATCHING_TV':18,
 'SITTING-DRESSING':16,
 'LYING_DOWN-COMPUTER_WORK':18,
 'SITTING-TOILET':80,
 'LYING_DOWN-EATING':18,
 'SITTING-SMOKING':16,
 'WALKING-WATCHING_TV':6,
 'WALKING-ELEVATOR':50,
 'STANDING_AND_MOVING-DRIVE_-_I_M_THE_DRIVER':100,
 'STANDING_IN_PLACE-DOING_LAUNDRY':69,
 'SITTING-PLAYING_PHONE-GAMES':84,
 'IN_A_CAR-':100,
 'STANDING_AND_MOVING-PLAYING_BASEBALL':82,
 'SITTING-MOTORBIKE':100,
 'STANDING_AND_MOVING-EXERCISING':83,
 'STANDING_AND_MOVING-COOKING':68,
 'WALKING-TEXTING':71,
 'BICYCLING-':24,
 'STANDING_IN_PLACE-COOKING':17,
 'STANDING_IN_PLACE-STRETCHING':17,
 'LYING_DOWN-TOILET':100,
 'SITTING-DRIVE_-_I_M_THE_DRIVER':12,
 'STANDING_AND_MOVING-STAIRS_-_GOING_DOWN':14,
 'STANDING_AND_MOVING-CLEANING':68,
 'LYING_DOWN-READING_A_BOOK':18,
 'WALKING-ON_A_BUS':64,
 'STANDING_IN_PLACE-COMPUTER_WORK':17,
 'STANDING_AND_MOVING-TEXTING':85,
 'WALKING-DOING_LAUNDRY':68,
 'STANDING_AND_MOVING-WASHING_DISHES':68,
 'STANDING_AND_MOVING-EATING':68,
 'STANDING_IN_PLACE-ON_A_TRAIN':65,
 'STANDING_IN_PLACE-BATHING_-_SHOWER':70,
 'STANDING_IN_PLACE-':17,
 'STANDING_IN_PLACE-TOILET':86,
 'STANDING_AND_MOVING-STRETCHING':68,
 'BICYCLING-EXERCISING':24,
 'BICYCLING-STATIONARY_BIKE':56,
 'RUNNING-EXERCISING':9,
 'STANDING_IN_PLACE-YOGA':78,
 'STANDING_IN_PLACE-ON_A_BUS':64,
 'STANDING_AND_MOVING-SKATEBOARDING':87,
 'SITTING-WATCHING_TV':16,
 'STANDING_AND_MOVING-COMPUTER_WORK':68,
 'LYING_DOWN-':18,
 'STANDING_IN_PLACE-EATING':17,
 'RUNNING-STAIRS_-_GOING_UP':88,
 'WALKING-IN_A_CAR':100,
 'SITTING-IN_A_CAR':100,
 'SITTING-DRINKING__NON-ALCOHOL_':61,
 'STANDING_AND_MOVING-SURFING_THE_INTERNET':85,
 'LYING_DOWN-DRINKING__NON-ALCOHOL_':18,
 'WALKING-TOILET':100,
 'SITTING-DANCING':100,
 'WALKING-CLEANING':6,
 'STANDING_IN_PLACE-SLEEPING':100,
 'SITTING-WASHING_DISHES':30,
 'EATING-':61,
 'WALKING-DRINKING__NON-ALCOHOL_':6,
 'WALKING-BATHING_-_SHOWER':100,
 'WALKING-EXERCISING':6,
 'STANDING_AND_MOVING-DRINKING__NON-ALCOHOL_':68,
 'RUNNING-':9,
 'SITTING-STRETCHING':77,
 'STANDING_IN_PLACE-PLAYING_VIDEOGAMES':91,
 'BICYCLING-SKATEBOARDING':100,
    'STANDING_AND_MOVING-IN_A_CAR':100
}

data2 = phone2.copy()

data2['Activity'] = data2['Activity'].map(mapping)
data2 = data2.reset_index(drop=True)

# %%
data2
# Out:
#           Dataset  Activity     X_Acc     Y_Acc     Z_Acc        X_Gyro  \
# 0              16        16  0.103585  0.116158 -9.955947    -79.322188
# 1              16        16  0.068557  0.095052 -9.981992    103.973742
# 2              16        16  0.072449  0.097747 -9.954599    -78.168447
# 3              16        16  0.098645  0.110171 -9.962982    -17.401751
# 4              16        16  0.085323  0.101339 -9.927955    104.708621
# ...           ...       ...       ...       ...       ...           ...
# 12630749       16        80  2.577490 -5.234764 -8.093220    992.922849
# 12630750       16        80  2.858306 -5.122049 -8.353828  -3144.589425
# 12630751       16        80  2.746040 -5.142556 -7.527546  -7950.090892
# 12630752       16        80  2.334096 -5.047653 -8.103998  -9383.832122
# 12630753       16        80  3.008145 -5.150340 -8.219108 -10146.224668
#
#                 Y_Gyro       Z_Gyro  Code                   TimeStamp  \
# ...

# %%
actividades = data['Activity'].unique()
actividades
# Out:
# array([ 16,   6,  24,  68,  85,  17,  18,  71, 100,  13,  12,  70,  84,
#         80,  62,  86,  61,  72,  50,  64,   9,  14])

# %%
data = data[data['Activity'] != 100]
data = data.reset_index(drop=True)

# %%
data
# Out:
#           Dataset  Activity     X_Acc     Y_Acc     Z_Acc        X_Gyro  \
# 0              16        16  0.103585  0.116158 -9.955947    -79.322188
# 1              16        16  0.068557  0.095052 -9.981992    103.973742
# 2              16        16  0.072449  0.097747 -9.954599    -78.168447
# 3              16        16  0.098645  0.110171 -9.962982    -17.401751
# 4              16        16  0.085323  0.101339 -9.927955    104.708621
# ...           ...       ...       ...       ...       ...           ...
# 12283353       16        80  2.577490 -5.234764 -8.093220    992.922849
# 12283354       16        80  2.858306 -5.122049 -8.353828  -3144.589425
# 12283355       16        80  2.746040 -5.142556 -7.527546  -7950.090892
# 12283356       16        80  2.334096 -5.047653 -8.103998  -9383.832122
# 12283357       16        80  3.008145 -5.150340 -8.219108 -10146.224668
#
#                 Y_Gyro       Z_Gyro  Code                   TimeStamp  \
# ...

# %% [markdown]
# ###Actividades phone 1

# %%
phone1 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone_FINAL/phone_1.dat')

# %%
phone1
# Out:
#           Dataset             Activity  X_Acc  Y_Acc  Z_Acc  X_Gyro  Y_Gyro  \
# 0              16             SITTING-   0.15   0.10  -9.67  -77.00  -79.79
# 1              16             SITTING-  -0.04   0.00  -9.88   45.11  -18.60
# 2              16             SITTING-   0.07  -0.03  -9.83  105.62   42.27
# 3              16             SITTING-   0.11  -0.01  -9.79  -15.86  -19.31
# 4              16             SITTING-   0.02   0.05  -9.82 -137.64  -80.93
# ...           ...                  ...    ...    ...    ...     ...     ...
# 12786395       16  LYING_DOWN-SLEEPING  -2.35   2.00 100.86  320.43   91.55
# 12786396       16  LYING_DOWN-SLEEPING  -2.37   1.88 100.80  457.76  228.88
# 12786397       16  LYING_DOWN-SLEEPING  -2.50   2.03 100.57  381.47  122.07
# 12786398       16  LYING_DOWN-SLEEPING  -2.40   1.87 100.70  473.02  137.33
# 12786399       16  LYING_DOWN-SLEEPING  -2.33   1.97 100.72  396.73   91.55
#
# ...

# %%
mapping = {
    'SITTING-ON_A_TRAIN':65,
 'WALKING-':6,
 'WALKING-DRIVE_-_I_M_THE_DRIVER':100,
 'SITTING-COMPUTER_WORK':16,
 'STANDING_AND_MOVING-SLEEPING':100,
 'SITTING-EATING':16,
 'STANDING_IN_PLACE-SURFING_THE_INTERNET':62,
 'RUNNING-PLAYING_BASEBALL':63,
 'STANDING_AND_MOVING-ON_A_BUS':64,
 'SITTING-PLAYING_VIDEOGAMES':16,
 'WALKING-SURFING_THE_INTERNET':71,
 'SITTING-COOKING':16,
 'STANDING_AND_MOVING-DOING_LAUNDRY':68,
 'STANDING_AND_MOVING-BATHING_-_SHOWER':70,
 'STANDING_IN_PLACE-TEXTING':62,
 'WALKING-COMPUTER_WORK':100,
 'BICYCLING-SURFING_THE_INTERNET':100,
 'LYING_DOWN-SURFING_THE_INTERNET':72,
 'WALKING-DRESSING':73,
 'STANDING_AND_MOVING-TOILET':100,
 'LYING_DOWN-TEXTING':72,
 'STANDING_IN_PLACE-DANCING':74,
 'SITTING-CLEANING':75,
 'STANDING_IN_PLACE-DRINKING__NON-ALCOHOL_':17,
 'STANDING_AND_MOVING-PLAYING_FRISBEE':76,
 'WALKING-STRETCHING':77,
 'SITTING-':16,
 'WALKING-TREADMILL':51,
 'WALKING-ON_A_TRAIN':65,
 'STANDING_IN_PLACE-WATCHING_TV':17,
 'WALKING-COOKING':6,
 'SITTING-SLEEPING':16,
 'STANDING_IN_PLACE-WASHING_DISHES':17,
 'STANDING_AND_MOVING-':68,
 'STANDING_AND_MOVING-ELEVATOR':50,
 'LYING_DOWN-STRETCHING':18,
 'RUNNING-TREADMILL':32,
 'STANDING_IN_PLACE-ELEVATOR':49,
 'SITTING-TEXTING':84,
 'STANDING_AND_MOVING-STAIRS_-_GOING_UP':13,
 'STANDING_AND_MOVING-WATCHING_TV':68,
 'WALKING-EATING':6,
 'LYING_DOWN-PLAYING_PHONE-GAMES':72,
 'STANDING_IN_PLACE-DRESSING':17,
 'SITTING-READING_A_BOOK':16,
 'STANDING_IN_PLACE-DRIVE_-_I_M_THE_DRIVER':100,
 'STANDING_IN_PLACE-PLAYING_PHONE-GAMES':62,
 'LYING_DOWN-SLEEPING':18,
 'LYING_DOWN-PLAYING_VIDEOGAMES':18,
 'WALKING-STAIRS_-_GOING_DOWN':14,
 'STANDING_IN_PLACE-CLEANING':75,
 'SITTING-SURFING_THE_INTERNET':16,
 'RUNNING-ELLIPTICAL_MACHINE':55,
 'SITTING-ON_A_BUS':64,
 'SITTING-YOGA':78,
 'STANDING_AND_MOVING-DRESSING':17,
 'WALKING-STAIRS_-_GOING_UP':13,
 'WALKING-SKATEBOARDING':79,
 'LYING_DOWN-WATCHING_TV':18,
 'SITTING-DRESSING':16,
 'LYING_DOWN-COMPUTER_WORK':18,
 'SITTING-TOILET':80,
 'LYING_DOWN-EATING':18,
 'SITTING-SMOKING':16,
 'WALKING-WATCHING_TV':6,
 'WALKING-ELEVATOR':50,
 'STANDING_AND_MOVING-DRIVE_-_I_M_THE_DRIVER':100,
 'STANDING_IN_PLACE-DOING_LAUNDRY':69,
 'SITTING-PLAYING_PHONE-GAMES':84,
 'IN_A_CAR-':100,
 'STANDING_AND_MOVING-PLAYING_BASEBALL':82,
 'SITTING-MOTORBIKE':100,
 'STANDING_AND_MOVING-EXERCISING':83,
 'STANDING_AND_MOVING-COOKING':68,
 'WALKING-TEXTING':71,
 'BICYCLING-':24,
 'STANDING_IN_PLACE-COOKING':17,
 'STANDING_IN_PLACE-STRETCHING':17,
 'LYING_DOWN-TOILET':100,
 'SITTING-DRIVE_-_I_M_THE_DRIVER':12,
 'STANDING_AND_MOVING-STAIRS_-_GOING_DOWN':14,
 'STANDING_AND_MOVING-CLEANING':68,
 'LYING_DOWN-READING_A_BOOK':18,
 'WALKING-ON_A_BUS':64,
 'STANDING_IN_PLACE-COMPUTER_WORK':17,
 'STANDING_AND_MOVING-TEXTING':85,
 'WALKING-DOING_LAUNDRY':68,
 'STANDING_AND_MOVING-WASHING_DISHES':68,
 'STANDING_AND_MOVING-EATING':68,
 'STANDING_IN_PLACE-ON_A_TRAIN':65,
 'STANDING_IN_PLACE-BATHING_-_SHOWER':70,
 'STANDING_IN_PLACE-':17,
 'STANDING_IN_PLACE-TOILET':86,
 'STANDING_AND_MOVING-STRETCHING':68,
 'BICYCLING-EXERCISING':24,
 'BICYCLING-STATIONARY_BIKE':56,
 'RUNNING-EXERCISING':9,
 'STANDING_IN_PLACE-YOGA':78,
 'STANDING_IN_PLACE-ON_A_BUS':64,
 'STANDING_AND_MOVING-SKATEBOARDING':87,
 'SITTING-WATCHING_TV':16,
 'STANDING_AND_MOVING-COMPUTER_WORK':68,
 'LYING_DOWN-':18,
 'STANDING_IN_PLACE-EATING':17,
 'RUNNING-STAIRS_-_GOING_UP':88,
 'WALKING-IN_A_CAR':100,
 'SITTING-IN_A_CAR':100,
 'SITTING-DRINKING__NON-ALCOHOL_':61,
 'STANDING_AND_MOVING-SURFING_THE_INTERNET':85,
 'LYING_DOWN-DRINKING__NON-ALCOHOL_':18,
 'WALKING-TOILET':100,
 'SITTING-DANCING':100,
 'WALKING-CLEANING':6,
 'STANDING_IN_PLACE-SLEEPING':100,
 'SITTING-WASHING_DISHES':30,
 'EATING-':61,
 'WALKING-DRINKING__NON-ALCOHOL_':6,
 'WALKING-BATHING_-_SHOWER':100,
 'WALKING-EXERCISING':6,
 'STANDING_AND_MOVING-DRINKING__NON-ALCOHOL_':68,
 'RUNNING-':9,
 'SITTING-STRETCHING':77,
 'STANDING_IN_PLACE-PLAYING_VIDEOGAMES':91,
 'BICYCLING-SKATEBOARDING':100,
    'STANDING_AND_MOVING-IN_A_CAR':100
}

data = phone1.copy()

data['Activity'] = data['Activity'].map(mapping)
data = data.reset_index(drop=True)

# %%
data = data[data['Activity'] != 100]
data = data.reset_index(drop=True)

# %%
data
# Out:
#           Dataset  Activity  X_Acc  Y_Acc  Z_Acc  X_Gyro  Y_Gyro  Z_Gyro  \
# 0              16        16   0.15   0.10  -9.67  -77.00  -79.79  436.33
# 1              16        16  -0.04   0.00  -9.88   45.11  -18.60  497.07
# 2              16        16   0.07  -0.03  -9.83  105.62   42.27  556.05
# 3              16        16   0.11  -0.01  -9.79  -15.86  -19.31  434.21
# 4              16        16   0.02   0.05  -9.82 -137.64  -80.93  556.76
# ...           ...       ...    ...    ...    ...     ...     ...     ...
# 12621595       16        18  -2.35   2.00 100.86  320.43   91.55 1205.44
# 12621596       16        18  -2.37   1.88 100.80  457.76  228.88 1098.63
# 12621597       16        18  -2.50   2.03 100.57  381.47  122.07 1144.41
# 12621598       16        18  -2.40   1.87 100.70  473.02  137.33 1052.86
# 12621599       16        18  -2.33   1.97 100.72  396.73   91.55 1159.67
#
#           Code                   TimeStamp  Frequency  User  Trial
# ...

# %% [markdown]
# ###Actividades phone 3

# %%
phone3 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/16.Dataset_16/phone_FINAL/phone_3.dat')

# %%
phone3
# Out:
#          Dataset  Activity  X_Acc   Y_Acc  Z_Acc    X_Gyro    Y_Gyro   Z_Gyro  \
# 0             16  WALKING-  35.89 -108.42  13.06    -61.04    732.44   305.19
# 1             16  WALKING-  42.09 -119.03  24.52    -61.04    732.44   305.19
# 2             16  WALKING-  47.91 -136.41  46.69 -17700.74  83803.83  4028.44
# 3             16  WALKING-  36.83 -137.54  43.97  -8423.11 118533.89 15808.59
# 4             16  WALKING-  16.53 -134.53  15.69   7568.59 146244.69 23194.07
# ...          ...       ...    ...     ...    ...       ...       ...      ...
# 6182010       16  SITTING-   0.05    0.02  -9.73  -1325.67     87.29   -46.61
# 6182011       16  SITTING-   0.06    0.04  -9.72  -1261.89   -522.31  -106.38
# 6182012       16  SITTING-   0.07    0.03  -9.71   -470.95     32.47   193.85
# 6182013       16  SITTING-   0.06    0.02  -9.73    200.88    217.01     6.56
# 6182014       16  SITTING-   0.06    0.01  -9.74    202.12     93.64  -176.53
#
# ...

# %%
mapping = {
    'SITTING-ON_A_TRAIN':65,
 'WALKING-':6,
 'WALKING-DRIVE_-_I_M_THE_DRIVER':100,
 'SITTING-COMPUTER_WORK':16,
 'STANDING_AND_MOVING-SLEEPING':100,
 'SITTING-EATING':16,
 'STANDING_IN_PLACE-SURFING_THE_INTERNET':62,
 'RUNNING-PLAYING_BASEBALL':63,
 'STANDING_AND_MOVING-ON_A_BUS':64,
 'SITTING-PLAYING_VIDEOGAMES':16,
 'WALKING-SURFING_THE_INTERNET':71,
 'SITTING-COOKING':16,
 'STANDING_AND_MOVING-DOING_LAUNDRY':68,
 'STANDING_AND_MOVING-BATHING_-_SHOWER':70,
 'STANDING_IN_PLACE-TEXTING':62,
 'WALKING-COMPUTER_WORK':100,
 'BICYCLING-SURFING_THE_INTERNET':100,
 'LYING_DOWN-SURFING_THE_INTERNET':72,
 'WALKING-DRESSING':73,
 'STANDING_AND_MOVING-TOILET':100,
 'LYING_DOWN-TEXTING':72,
 'STANDING_IN_PLACE-DANCING':74,
 'SITTING-CLEANING':75,
 'STANDING_IN_PLACE-DRINKING__NON-ALCOHOL_':17,
 'STANDING_AND_MOVING-PLAYING_FRISBEE':76,
 'WALKING-STRETCHING':77,
 'SITTING-':16,
 'WALKING-TREADMILL':51,
 'WALKING-ON_A_TRAIN':65,
 'STANDING_IN_PLACE-WATCHING_TV':17,
 'WALKING-COOKING':6,
 'SITTING-SLEEPING':16,
 'STANDING_IN_PLACE-WASHING_DISHES':17,
 'STANDING_AND_MOVING-':68,
 'STANDING_AND_MOVING-ELEVATOR':50,
 'LYING_DOWN-STRETCHING':18,
 'RUNNING-TREADMILL':32,
 'STANDING_IN_PLACE-ELEVATOR':49,
 'SITTING-TEXTING':84,
 'STANDING_AND_MOVING-STAIRS_-_GOING_UP':13,
 'STANDING_AND_MOVING-WATCHING_TV':68,
 'WALKING-EATING':6,
 'LYING_DOWN-PLAYING_PHONE-GAMES':72,
 'STANDING_IN_PLACE-DRESSING':17,
 'SITTING-READING_A_BOOK':16,
 'STANDING_IN_PLACE-DRIVE_-_I_M_THE_DRIVER':100,
 'STANDING_IN_PLACE-PLAYING_PHONE-GAMES':62,
 'LYING_DOWN-SLEEPING':18,
 'LYING_DOWN-PLAYING_VIDEOGAMES':18,
 'WALKING-STAIRS_-_GOING_DOWN':14,
 'STANDING_IN_PLACE-CLEANING':75,
 'SITTING-SURFING_THE_INTERNET':16,
 'RUNNING-ELLIPTICAL_MACHINE':55,
 'SITTING-ON_A_BUS':64,
 'SITTING-YOGA':78,
 'STANDING_AND_MOVING-DRESSING':17,
 'WALKING-STAIRS_-_GOING_UP':13,
 'WALKING-SKATEBOARDING':79,
 'LYING_DOWN-WATCHING_TV':18,
 'SITTING-DRESSING':16,
 'LYING_DOWN-COMPUTER_WORK':18,
 'SITTING-TOILET':80,
 'LYING_DOWN-EATING':18,
 'SITTING-SMOKING':16,
 'WALKING-WATCHING_TV':6,
 'WALKING-ELEVATOR':50,
 'STANDING_AND_MOVING-DRIVE_-_I_M_THE_DRIVER':100,
 'STANDING_IN_PLACE-DOING_LAUNDRY':69,
 'SITTING-PLAYING_PHONE-GAMES':84,
 'IN_A_CAR-':100,
 'STANDING_AND_MOVING-PLAYING_BASEBALL':82,
 'SITTING-MOTORBIKE':100,
 'STANDING_AND_MOVING-EXERCISING':83,
 'STANDING_AND_MOVING-COOKING':68,
 'WALKING-TEXTING':71,
 'BICYCLING-':24,
 'STANDING_IN_PLACE-COOKING':17,
 'STANDING_IN_PLACE-STRETCHING':17,
 'LYING_DOWN-TOILET':100,
 'SITTING-DRIVE_-_I_M_THE_DRIVER':12,
 'STANDING_AND_MOVING-STAIRS_-_GOING_DOWN':14,
 'STANDING_AND_MOVING-CLEANING':68,
 'LYING_DOWN-READING_A_BOOK':18,
 'WALKING-ON_A_BUS':64,
 'STANDING_IN_PLACE-COMPUTER_WORK':17,
 'STANDING_AND_MOVING-TEXTING':85,
 'WALKING-DOING_LAUNDRY':68,
 'STANDING_AND_MOVING-WASHING_DISHES':68,
 'STANDING_AND_MOVING-EATING':68,
 'STANDING_IN_PLACE-ON_A_TRAIN':65,
 'STANDING_IN_PLACE-BATHING_-_SHOWER':70,
 'STANDING_IN_PLACE-':17,
 'STANDING_IN_PLACE-TOILET':86,
 'STANDING_AND_MOVING-STRETCHING':68,
 'BICYCLING-EXERCISING':24,
 'BICYCLING-STATIONARY_BIKE':56,
 'RUNNING-EXERCISING':9,
 'STANDING_IN_PLACE-YOGA':78,
 'STANDING_IN_PLACE-ON_A_BUS':64,
 'STANDING_AND_MOVING-SKATEBOARDING':87,
 'SITTING-WATCHING_TV':16,
 'STANDING_AND_MOVING-COMPUTER_WORK':68,
 'LYING_DOWN-':18,
 'STANDING_IN_PLACE-EATING':17,
 'RUNNING-STAIRS_-_GOING_UP':88,
 'WALKING-IN_A_CAR':100,
 'SITTING-IN_A_CAR':100,
 'SITTING-DRINKING__NON-ALCOHOL_':61,
 'STANDING_AND_MOVING-SURFING_THE_INTERNET':85,
 'LYING_DOWN-DRINKING__NON-ALCOHOL_':18,
 'WALKING-TOILET':100,
 'SITTING-DANCING':100,
 'WALKING-CLEANING':6,
 'STANDING_IN_PLACE-SLEEPING':100,
 'SITTING-WASHING_DISHES':30,
 'EATING-':61,
 'WALKING-DRINKING__NON-ALCOHOL_':6,
 'WALKING-BATHING_-_SHOWER':100,
 'WALKING-EXERCISING':6,
 'STANDING_AND_MOVING-DRINKING__NON-ALCOHOL_':68,
 'RUNNING-':9,
 'SITTING-STRETCHING':77,
 'STANDING_IN_PLACE-PLAYING_VIDEOGAMES':91,
 'BICYCLING-SKATEBOARDING':100,
    'STANDING_AND_MOVING-IN_A_CAR':100
}

data3 = phone3.copy()

data3['Activity'] = data3['Activity'].map(mapping)
data3 = data3.reset_index(drop=True)

# %%
data3 = data3[data3['Activity'] != 100]
data3 = data3.reset_index(drop=True)

# %%
data3
# Out:
#          Dataset  Activity  X_Acc   Y_Acc  Z_Acc    X_Gyro    Y_Gyro   Z_Gyro  \
# 0             16         6  35.89 -108.42  13.06    -61.04    732.44   305.19
# 1             16         6  42.09 -119.03  24.52    -61.04    732.44   305.19
# 2             16         6  47.91 -136.41  46.69 -17700.74  83803.83  4028.44
# 3             16         6  36.83 -137.54  43.97  -8423.11 118533.89 15808.59
# 4             16         6  16.53 -134.53  15.69   7568.59 146244.69 23194.07
# ...          ...       ...    ...     ...    ...       ...       ...      ...
# 6173210       16        16   0.05    0.02  -9.73  -1325.67     87.29   -46.61
# 6173211       16        16   0.06    0.04  -9.72  -1261.89   -522.31  -106.38
# 6173212       16        16   0.07    0.03  -9.71   -470.95     32.47   193.85
# 6173213       16        16   0.06    0.02  -9.73    200.88    217.01     6.56
# 6173214       16        16   0.06    0.01  -9.74    202.12     93.64  -176.53
#
# ...

# %% [markdown]
# ##Resampling

# %% [markdown]
# ###Resampling del phone 2

# %%
final2 = resample_dataframe(data2)

# %%
final2
# Out:
#           Dataset  Activity     X_Acc     Y_Acc     Z_Acc        X_Gyro  \
# 0              16        16  0.103585  0.116158 -9.955947    -79.322188
# 1              16        16  0.103585  0.116158 -9.955947    -79.322188
# 2              16        16  0.103585  0.116158 -9.955947    -79.322188
# 3              16        16  0.068557  0.095052 -9.981992    103.973742
# 4              16        16  0.072449  0.097747 -9.954599    -78.168447
# ...           ...       ...       ...       ...       ...           ...
# 15354192       16        80  2.746040 -5.142556 -7.527546  -7950.090892
# 15354193       16        80  2.334096 -5.047653 -8.103998  -9383.832122
# 15354194       16        80  2.334096 -5.047653 -8.103998  -9383.832122
# 15354195       16        80  3.008145 -5.150340 -8.219108 -10146.224668
# 15354196       16        80  3.008145 -5.150340 -8.219108 -10146.224668
#
#                 Y_Gyro       Z_Gyro  Code                   TimeStamp  \
# ...

# %%
final2.to_csv('/content/drive/MyDrive/TESIS_DATASET/Datasets definitivos_CSV/dataset16_phone_2.csv', index=False)

# %% [markdown]
# ###Resampling del phone 1

# %%
final = resample_dataframe(data)

# %%
final
# Out:
#           Dataset  Activity  X_Acc  Y_Acc  Z_Acc  X_Gyro  Y_Gyro  Z_Gyro  \
# 0              16        16   0.15   0.10  -9.67  -77.00  -79.79  436.33
# 1              16        16  -0.04   0.00  -9.88   45.11  -18.60  497.07
# 2              16        16   0.07  -0.03  -9.83  105.62   42.27  556.05
# 3              16        16   0.11  -0.01  -9.79  -15.86  -19.31  434.21
# 4              16        16   0.02   0.05  -9.82 -137.64  -80.93  556.76
# ...           ...       ...    ...    ...    ...     ...     ...     ...
# 15776995       16        18  -2.37   1.88 100.80  457.76  228.88 1098.63
# 15776996       16        18  -2.37   1.88 100.80  457.76  228.88 1098.63
# 15776997       16        18  -2.50   2.03 100.57  381.47  122.07 1144.41
# 15776998       16        18  -2.40   1.87 100.70  473.02  137.33 1052.86
# 15776999       16        18  -2.33   1.97 100.72  396.73   91.55 1159.67
#
#           Code                   TimeStamp  Frequency  User  Trial
# ...

# %%
final.to_csv('/content/drive/MyDrive/TESIS_DATASET/Datasets definitivos_CSV/dataset16_phone_1.csv', index=False)

# %% [markdown]
# ###Resampling del phone 3

# %%
final3 = resample_dataframe(data3)

# %%
final3
# Out:
#          Dataset  Activity  X_Acc   Y_Acc  Z_Acc    X_Gyro    Y_Gyro   Z_Gyro  \
# 0             16         6  35.89 -108.42  13.06    -61.04    732.44   305.19
# 1             16         6  42.09 -119.03  24.52    -61.04    732.44   305.19
# 2             16         6  47.91 -136.41  46.69 -17700.74  83803.83  4028.44
# 3             16         6  36.83 -137.54  43.97  -8423.11 118533.89 15808.59
# 4             16         6  16.53 -134.53  15.69   7568.59 146244.69 23194.07
# ...          ...       ...    ...     ...    ...       ...       ...      ...
# 7716513       16        16   0.06    0.04  -9.72  -1261.89   -522.31  -106.38
# 7716514       16        16   0.07    0.03  -9.71   -470.95     32.47   193.85
# 7716515       16        16   0.06    0.02  -9.73    200.88    217.01     6.56
# 7716516       16        16   0.06    0.02  -9.73    200.88    217.01     6.56
# 7716517       16        16   0.06    0.01  -9.74    202.12     93.64  -176.53
#
# ...

# %%
final3.to_csv('/content/drive/MyDrive/TESIS_DATASET/Datasets definitivos_CSV/dataset16_phone_3.csv', index=False)

# %%
prueba3 = pd.read_csv('/content/drive/MyDrive/TESIS_DATASET/Datasets definitivos_CSV/dataset16_phone_3.csv')

# %%
prueba3
# Out:
#          Dataset  Activity  X_Acc   Y_Acc  Z_Acc    X_Gyro    Y_Gyro   Z_Gyro  \
# 0             16         6  35.89 -108.42  13.06    -61.04    732.44   305.19
# 1             16         6  42.09 -119.03  24.52    -61.04    732.44   305.19
# 2             16         6  47.91 -136.41  46.69 -17700.74  83803.83  4028.44
# 3             16         6  36.83 -137.54  43.97  -8423.11 118533.89 15808.59
# 4             16         6  16.53 -134.53  15.69   7568.59 146244.69 23194.07
# ...          ...       ...    ...     ...    ...       ...       ...      ...
# 7716513       16        16   0.03    0.09  -9.79     60.30    -28.22    -4.58
# 7716514       16        16  -7.20    6.25   2.84    150.13     90.25    29.05
# 7716515       16        68   0.03    0.36  -9.75   -250.88    -68.49    56.59
# 7716516       16        18   0.48    1.06  -9.67    -76.81     33.89    -0.47
# 7716517       16        16   5.61   -0.49  -7.95    -31.09    -43.16    -8.67
#
# ...

# %% [markdown]
# ##Describe

# %% [markdown]
# ###Describe del phone 2

# %% [markdown]
# ####Después

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

description = final2.describe()

# %%
description
# Out:
#           Dataset    Activity       X_Acc       Y_Acc       Z_Acc      X_Gyro  \
# count 15354197.00 15354197.00 15354197.00 15354197.00 15354197.00 15354197.00
# mean        16.00       25.66        3.01        1.02        5.35      -48.00
# std          0.00       21.14       19.13       16.10       34.05    20548.81
# min         16.00        6.00     -366.27     -349.16     -384.81  -966641.37
# 25%         16.00       16.00       -0.80       -0.98       -9.81     -355.13
# 50%         16.00       17.00        0.19       -0.05       -8.06      -28.56
# 75%         16.00       18.00        1.63        1.86        5.11      244.14
# max         16.00       86.00      384.80      305.14      384.80   922522.18
#
#            Y_Gyro      Z_Gyro        Code   Frequency        User  Trial
# count 15354197.00 15354197.00 15354197.00 15354197.00 15354197.00   0.00
# mean       159.64     -124.67      300.44       50.00       34.49    NaN
# ...

# %% [markdown]
# ####Antes

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

description = data2.describe()
description
# Out:
#           Dataset    Activity       X_Acc       Y_Acc       Z_Acc      X_Gyro  \
# count 12283358.00 12283358.00 12283358.00 12283358.00 12283358.00 12283358.00
# mean        16.00       25.66        3.00        1.02        5.35      -48.39
# std          0.00       21.14       19.13       16.10       34.05    20519.70
# min         16.00        6.00     -366.27     -349.16     -384.81  -966641.37
# 25%         16.00       16.00       -0.80       -0.98       -9.81     -355.07
# 50%         16.00       17.00        0.19       -0.05       -8.06      -28.57
# 75%         16.00       18.00        1.63        1.86        5.10      244.14
# max         16.00       86.00      384.80      305.14      384.80   922522.18
#
#            Y_Gyro      Z_Gyro        Code   Frequency        User  Trial
# count 12283358.00 12283358.00 12283358.00 12283358.00 12283358.00   0.00
# mean       155.64     -123.85      300.44       40.00       34.49    NaN
# ...

# %% [markdown]
# ###Describe del phone 1

# %% [markdown]
# ####Después

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

description = final.describe()
description
# Out:
#           Dataset    Activity       X_Acc       Y_Acc       Z_Acc      X_Gyro  \
# count 15777000.00 15777000.00 15777000.00 15777000.00 15777000.00 15777000.00
# mean        16.00       26.99       -1.09        6.78       22.20      189.52
# std          0.00       21.94       17.61       30.36       48.51    23523.95
# min         16.00        6.00     -192.41     -192.41     -192.41 -1019146.19
# 25%         16.00       16.00       -2.22       -1.25       -9.48      -68.30
# 50%         16.00       18.00       -0.11        0.07       -1.29       72.75
# 75%         16.00       18.00        1.39        3.25       84.85      427.25
# max         16.00       86.00      192.40      192.40      192.40  1417757.56
#
#            Y_Gyro      Z_Gyro        Code   Frequency        User  Trial
# count 15777000.00 15777000.00 15777000.00 15777000.00 15777000.00   0.00
# mean      -160.23      212.74      300.36       50.00       15.14    NaN
# ...

# %% [markdown]
# ####Antes

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

description = data.describe()
description
# Out:
#           Dataset    Activity       X_Acc       Y_Acc       Z_Acc      X_Gyro  \
# count 12621600.00 12621600.00 12621600.00 12621600.00 12621600.00 12621600.00
# mean        16.00       26.99       -1.09        6.78       22.20      193.02
# std          0.00       21.94       17.60       30.36       48.51    23533.09
# min         16.00        6.00     -192.41     -192.41     -192.41 -1019146.19
# 25%         16.00       16.00       -2.22       -1.25       -9.48      -68.26
# 50%         16.00       18.00       -0.11        0.07       -1.28       72.80
# 75%         16.00       18.00        1.39        3.25       84.89      427.25
# max         16.00       86.00      192.40      192.40      192.40  1417757.56
#
#            Y_Gyro      Z_Gyro        Code   Frequency        User  Trial
# count 12621600.00 12621600.00 12621600.00 12621600.00 12621600.00   0.00
# mean      -164.83      216.34      300.36       40.00       15.14    NaN
# ...

# %% [markdown]
# ###Describe del phone 3

# %% [markdown]
# ####Después

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

description = final3.describe()
description
# Out:
#          Dataset   Activity      X_Acc      Y_Acc      Z_Acc      X_Gyro  \
# count 7716518.00 7716518.00 7716518.00 7716518.00 7716518.00  7716518.00
# mean       16.00      20.26       0.04       1.27      -4.84       42.19
# std         0.00      15.29       5.72      13.53      14.95    20835.98
# min        16.00       6.00    -332.11    -337.37    -282.22 -1199391.05
# 25%        16.00      16.00      -0.77      -0.21      -9.75      -87.15
# 50%        16.00      18.00      -0.15       0.17      -9.67        0.78
# 75%        16.00      18.00       0.24       0.95      -5.22       83.35
# max        16.00      84.00     300.45     969.36     519.91   982134.32
#
#            Y_Gyro     Z_Gyro       Code  Frequency       User  Trial
# count  7716518.00 7716518.00 7716518.00 7716518.00 7716518.00   0.00
# mean        -8.27      89.21     300.15      50.00      49.13    NaN
# std      22553.32   16756.31       0.43       0.00       3.46    NaN
# ...

# %% [markdown]
# ####Antes

# %%
pd.set_option('display.float_format', '{:.2f}'.format)

description = data3.describe()
description
# Out:
#          Dataset   Activity      X_Acc      Y_Acc      Z_Acc      X_Gyro  \
# count 6173215.00 6173215.00 6173215.00 6173215.00 6173215.00  6173215.00
# mean       16.00      20.26       0.04       1.27      -4.83       42.03
# std         0.00      15.29       5.71      13.52      14.96    20850.25
# min        16.00       6.00    -332.11    -337.37    -282.22 -1199391.05
# 25%        16.00      16.00      -0.77      -0.21      -9.75      -87.16
# 50%        16.00      18.00      -0.15       0.17      -9.67        0.78
# 75%        16.00      18.00       0.24       0.95      -5.22       83.30
# max        16.00      84.00     300.45     969.36     519.91   982134.32
#
#            Y_Gyro     Z_Gyro       Code  Frequency       User  Trial
# count  6173215.00 6173215.00 6173215.00 6173215.00 6173215.00   0.00
# mean        -6.19      89.93     300.15      40.00      49.13    NaN
# std      22592.00   16757.68       0.43       0.00       3.46    NaN
# ...

# %% [markdown]
# ##Análisis gráfico del dataset 16 Smartphone

# %% [markdown]
# ###Valores Válidos Acelerometro

# %%
#Phone 2
grafico_acelerometro_valido(final2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Phone 1
grafico_acelerometro_valido(final)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Phone 3
grafico_acelerometro_valido(final3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Valores Máximo y Mínimos Acelerometro

# %%
#Phone 2
grafico_acelerometro_max_min(final2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Phone 1
grafico_acelerometro_max_min(final)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Phone 3
grafico_acelerometro_max_min(final3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ### Valores Válidos Giroscopio

# %%
#Phone 1
grafico_giroscopio_valido(final)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###Valores Máximo y Mínimos Giroscopio

# %%
#Phone 2
grafico_giroscopio_max_min(final2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Phone 1
grafico_giroscopio_max_min(final)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Phone 3
grafico_giroscopio_max_min(final3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###Actividades válidas

# %%
import plotly.graph_objects as go

def grafico_activity(phone_2):

    columna_actividad = phone_2['Activity']

    valores_validos = columna_actividad.notnull().sum()
    valores_nulos = columna_actividad.isnull().sum()

    porcentaje_validos = (valores_validos / len(columna_actividad)) * 100
    porcentaje_nulos = (valores_nulos / len(columna_actividad)) * 100

    labels = ['Valores válidos', 'Valores nulos']
    values = [porcentaje_validos, porcentaje_nulos]

    fig = go.Figure(data=[go.Pie(labels=labels, values=values)])

    fig.update_layout(
        title="Porcentaje de valores nulos y valores válidos en la columna 'Activity'"
    )

    fig.show()
grafico_activity(phone_2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Phone 2
grafico_activity(final2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Phone 1
grafico_activity(final)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Phone 3
grafico_activity(final3)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ###Ubicacion

# %%
import plotly.graph_objects as go
import pandas as pd

def grafico_activity(phone_2):

    columna_actividad = phone_2['Location']

    valores_validos = columna_actividad.notnull().sum()
    valores_nulos = columna_actividad.isnull().sum()

    porcentaje_validos = (valores_validos / len(columna_actividad)) * 100
    porcentaje_nulos = (valores_nulos / len(columna_actividad)) * 100

    labels = ['Valores válidos', 'Valores nulos']
    values = [porcentaje_validos, porcentaje_nulos]

    fig = go.Figure(data=[go.Pie(labels=labels, values=values)])

    fig.update_layout(
        title="Porcentaje de valores nulos y valores válidos en la columna 'Location'"
    )

    fig.show()
grafico_activity(phone_2)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
